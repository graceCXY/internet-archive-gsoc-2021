# %% [markdown]
# # URL Generation With Advanced Search

# %%
import numpy as np 
import pandas as pd
import re
import requests
import datetime
import dateparser
import json 

from bs4 import BeautifulSoup

import gspread
from gspread_dataframe import set_with_dataframe
# Out:
# /Users/xinyuechen/.pyenv/versions/3.7.5/lib/python3.7/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## Load Data

# %%
journal_dump = pd.read_json("tr.wikipedia.org.journal.20210614.json.gz", lines = True)
journal_dump.head()
# Out:
#                        a                                                  c
# 0  1 + 2 + 3 + 4 + · · ·  {{Akademik dergi kaynağı\n| soyadı = Lepowsky ...
# 1            12 Victoria  {{Akademik dergi kaynağı\n | ad1    = B.\n | s...
# 2   1,3,5-Triklorobenzen  {{Akademik dergi kaynağı|soyadı=Jaw|ad=Ching-G...
# 3      141 Likya depremi  {{Akademik dergi kaynağı | url=http://blackmed...
# 4      141 Likya depremi  {{Akademik dergi kaynağı | url=http://www.nat-...

# %%
journal_dump.shape
# Out:
# (14624, 2)

# %%
def citation_string_into_list(citation):
    citation = re.sub('[{}]', '', citation)
    citation_list = citation.split("|")
    return citation_list

# %%
# Test function
citations = journal_dump['c'].apply(citation_string_into_list)
citations[0:5][1]
# Out:
# ['Akademik dergi kaynağı\n ',
#  ' ad1    = B.\n ',
#  ' soyadı1     = Carry\n ',
#  'başlık= Density of asteroids\n ',
#  'iş= Planetary and Space Science\n ',
#  'cilt= 73\n ',
#  'sayfalar=98-118',
#  'tarih= December 2012\n ',
#  'doi= 10.1016/j.pss.2012.03.009\n ',
#  'bibcode= 2012P&SS...73...98C\n ',
#  'postscript= .\n',
#  'arxiv = 1203.4336\n ']

# %%
### change this part for different alias for different languages 
journal_aliases = ['journal', 'newspaper', 'magazine', 'work','website',  'periodical', 
                       'encyclopedia', 'encyclopaedia', 'dictionary', 'mailinglist','dergi', 'gazete', 
                       'eser', 'çalışma', 'iş', 'websitesi', 'süreliyayın', 'ansiklopedi', 'sözlük', 'program']
    
date_aliases = ['date', 'air-date', 'airdate', 'tarih']
    
year_aliases = ['year', 'yıl', 'sene']
    
volume_aliases = ['volume', 'cilt']
    
issue_aliases = ['issue', 'number', 'sayı', 'numara']

page_aliases = ['p', 'page', 's', 'sayfa']
pages_aliases = ['pp', 'pages', 'ss', 'sayfalar']

url_aliases = ['url', 'URL', 'katkı-url', 'chapter-url', 'contribution-url', 'entry-url', 
               'article-url', 'section-url']

title_aliases= ['title', 'başlık']

doi_aliases = ['doi', 'DOI', 'pmid', 'PMID', 'jstor']

# %%
# Parsing a wikipedia citation data
def parse_citation_data(citation):

    citation = re.sub('[{}]', '', citation)
    citation_list = citation.split("|")
    
    journal = ""
    sim_id = ""
    volume = ""
    issue = ""
    
    title = ""
    page = ""
    
    url = ""
    doi = ""
    
    date = ""
    month_str = ""
    year = 0
    
    for field in citation_list:
        field = field.strip()
        
        # find journal title
        for j_a in journal_aliases:
            journal_regex = j_a + "(\s{0,})="
            if re.match(re.compile(journal_regex), field):
                journal = field.split("=")[1].strip()
                journal = re.sub('[^A-Za-z0-9 ]+', '', journal)
                if journal != "":
                    sim_id = journal.lower()
                    sim_id_lst = sim_id.split()
                    sim_id = "-".join(sim_id_lst)
                    sim_id = "sim_" + sim_id
                break
   
        # find journal volume 
        for v_a in volume_aliases:
            volume_regex = v_a + "(\s{0,})="
            if re.match(re.compile(volume_regex), field):
                volume = field.split("=")[1].strip()
                volume = re.sub('[^0-9]+', '', volume)
                break
            
        # find journal issue
        for i_a in issue_aliases:
            issue_regex = i_a + "(\s{0,})="
            if re.match(issue_regex, field):
                issue = field.split("=")[1].strip()
                break
        
        # find journal year
        for y_a in year_aliases:
            year_regex = y_a + "(\s{0,})="
            if re.match(year_regex, field):
                year = field.split("=")[1].strip()
                date = re.sub('[^0-9]+', '', year)
                try:
                    year = int(date)
                except:
                    year = 0
                break
            
        # find journal date
        for d_a in date_aliases:
            date_regex = d_a + "(\s{0,})="
            if re.match(date_regex, field):
                date = field.split("=")[1].strip()
                
#                 print("this should be a date " + date)

                try:
                    year = int(date)
                    date = str(year)
                except:
                    # use the python library for parsing
                    parsed_date = dateparser.parse(date)
                    if parsed_date != None:
                        if parsed_date.year < 2021 and parsed_date.year > 1800:
                            year = parsed_date.year
                            date = str(year)

                        if parsed_date.month < 10:
                            month = parsed_date.month
                            month_str = "0" + str(month)
                        else:
                            month = parsed_date.month
                            month_str = str(month)
                            
#                         print(month_str)

                        if month_str != "":
                            date = date + "-" + month_str 
                break
        
         # find existing url
        for u_a in url_aliases:
            url_regex = u_a + "(\s{0,})="
            if re.match(url_regex, field):
                url = field.split("=")[1].strip()
                break
            
        # find page field 
        for p_a in page_aliases:
            page_regex = p_a + "(\s{0,})="
            if re.match(page_regex, field):
                page = field.split("=")[1].strip()
                if "[" in page:
                    page = ""
                break
                
        # find pages field
        for ps_a in pages_aliases:
            pages_regex = ps_a + "(\s{0,})="
            if re.match(pages_regex, field):
                pages = field.split("=")[1].strip()
                if "[" not in pages:
                    if "-" in pages:
                        page = pages.split("-")[0].strip()
                    elif "–" in pages:
                        page = pages.split("–")[0].strip()
                    else:
                        page = ""
                        
                break
                
        # find page field 
        for t_a in title_aliases:
            title_regex = t_a + "(\s{0,})="
            if re.match(title_regex, field):
                title = field.split("=")[1].strip()
                if "[" in title:
                    title = ""
                break
                
        # find field 
        for doi_a in doi_aliases:
            doi_regex = doi_a + "(\s{0,})="
            if re.match(doi_regex, field):
                doi = field.split("=")[1].strip()
                break
            
    return {'journal': journal, 'sim_id': sim_id, 'date': date, 'year': year, 
            'volume': volume, 'issue': issue, 'title': title, 'page': page, 
            'url': url, 'doi': doi}

# %%
# parse citation data test 
cite_test = "{{Cite journal | last1 = Lewis | first1 = Herbert | date = June 2001 | title = The Passion of Franz Boas | journal = [[American Anthropologist]] | volume = 103 | issue = 2| pages = 447–467 | url = https://archive.org/details/sim_american-anthropologist_2001-06_103_2/page/447/mode/2up | doi=10.1525/aa.2001.103.2.447}}"
parse_citation_data(cite_test)
# Out:
# {'journal': 'American Anthropologist',
#  'sim_id': 'sim_american-anthropologist',
#  'date': '2001-06',
#  'year': 2001,
#  'volume': '103',
#  'issue': '2',
#  'title': 'The Passion of Franz Boas',
#  'page': '447',
#  'url': 'https://archive.org/details/sim_american-anthropologist_2001-06_103_2/page/447/mode/2up',
#  'doi': '10.1525/aa.2001.103.2.447'}

# %%
cite_test2 = journal_dump.loc[2, 'c']
print(cite_test2)
parse_citation_data(cite_test2)
# Out:
# {{Akademik dergi kaynağı|soyadı=Jaw|ad=Ching-Guang|soyadı2=Chen|ad2=I-Ming|soyadı3=Yen|ad3=Jui-Hung|soyadı4=Wang|ad4=Yei-Shung|tarih=Aralık 1999|başlık=Partial solubility parameters of chlorobenzene and chlorophenol compounds at equilibrium distribution in two immiscible phases|dergi=Chemosphere|cilt=39|sayı=15|sayfalar=2607-2620|doi=10.1016/s0045-6535(99)00173-3|issn=0045-6535}}
# {'journal': 'Chemosphere',
#  'sim_id': 'sim_chemosphere',
#  'date': '1999-12',
#  'year': 1999,
#  'volume': '39',
#  'issue': '15',
#  'title': 'Partial solubility parameters of chlorobenzene and chlorophenol compounds at equilibrium distribution in two immiscible phases',
#  'page': '2607',
#  'url': '',
#  'doi': '10.1016/s0045-6535(99)00173-3'}

# %%
parsed_citations = journal_dump['c'].apply(parse_citation_data)
parsed_citations_df = pd.DataFrame(parsed_citations.tolist())

# %%
parsed_citations_df.head()
# Out:
#                                          journal  \
# 0                                Gncel Matematik
# 1                    Planetary and Space Science
# 2                                    Chemosphere
# 3  Journal of Black SeaMediterranean Environment
# 4      Natural Hazards and Earth System Sciences
#
#                                               sim_id     date  year volume  \
# 0                                sim_gncel-matematik     1999  1999    248
# 1                    sim_planetary-and-space-science  2012-12  2012     73
# 2                                    sim_chemosphere  1999-12  1999     39
# 3  sim_journal-of-black-seamediterranean-environment     2007  2007     13
# 4      sim_natural-hazards-and-earth-system-sciences     2011  2011     11
#
#   issue                                              title  page  \
# 0              Nokta operatör cebirleri ve zeta fonksiyonu   327
# 1                                     Density of asteroids    98
# 2    15  Partial solubility parameters of chlorobenzene...  2607
# 3        Traces of Historical earthquakes in the ancien...   241
# 4        Revision of the tsunami catalogue affecting Tu...
#
#                                                  url  \
# 0                  http://arxiv.org/abs/math/9909178
# 1
# 2
# 3  http://blackmeditjournal.org/pdf/4-%20Traces%2...
# 4  http://www.nat-hazards-earth-syst-sci.net/11/2...
#
#                              doi
# 0
# 1      10.1016/j.pss.2012.03.009
# 2  10.1016/s0045-6535(99)00173-3
# 3
# 4      10.5194/nhess-11-273-2011

# %%
parsed_citations_df = pd.concat([journal_dump, parsed_citations_df], axis=1)
parsed_citations_df.head()
# Out:
#                        a                                                  c  \
# 0  1 + 2 + 3 + 4 + · · ·  {{Akademik dergi kaynağı\n| soyadı = Lepowsky ...
# 1            12 Victoria  {{Akademik dergi kaynağı\n | ad1    = B.\n | s...
# 2   1,3,5-Triklorobenzen  {{Akademik dergi kaynağı|soyadı=Jaw|ad=Ching-G...
# 3      141 Likya depremi  {{Akademik dergi kaynağı | url=http://blackmed...
# 4      141 Likya depremi  {{Akademik dergi kaynağı | url=http://www.nat-...
#
#                                          journal  \
# 0                                Gncel Matematik
# 1                    Planetary and Space Science
# 2                                    Chemosphere
# 3  Journal of Black SeaMediterranean Environment
# 4      Natural Hazards and Earth System Sciences
#
#                                               sim_id     date  year volume  \
# 0                                sim_gncel-matematik     1999  1999    248
# 1                    sim_planetary-and-space-science  2012-12  2012     73
# 2                                    sim_chemosphere  1999-12  1999     39
# 3  sim_journal-of-black-seamediterranean-environment     2007  2007     13
# 4      sim_natural-hazards-and-earth-system-sciences     2011  2011     11
#
#   issue                                              title  page  \
# 0              Nokta operatör cebirleri ve zeta fonksiyonu   327
# 1                                     Density of asteroids    98
# 2    15  Partial solubility parameters of chlorobenzene...  2607
# 3        Traces of Historical earthquakes in the ancien...   241
# 4        Revision of the tsunami catalogue affecting Tu...
#
#                                                  url  \
# 0                  http://arxiv.org/abs/math/9909178
# 1
# 2
# 3  http://blackmeditjournal.org/pdf/4-%20Traces%2...
# 4  http://www.nat-hazards-earth-syst-sci.net/11/2...
#
#                              doi
# 0
# 1      10.1016/j.pss.2012.03.009
# 2  10.1016/s0045-6535(99)00173-3
# 3
# 4      10.5194/nhess-11-273-2011

# %% [markdown]
# ## Extract Desired Dataframe

# %% [markdown]
# ### Citations without Existing Urls

# %%
df_wo_url = parsed_citations_df[parsed_citations_df['url'] == ""]
print("There are " + str(df_wo_url.shape[0]) + " without existing urls out of " + str(parsed_citations_df.shape[0]))
df_wo_url.head()
# Out:
# There are 8153 without existing urls out of 14624
#                       a                                                  c  \
# 1           12 Victoria  {{Akademik dergi kaynağı\n | ad1    = B.\n | s...
# 2  1,3,5-Triklorobenzen  {{Akademik dergi kaynağı|soyadı=Jaw|ad=Ching-G...
# 5    1481 Rodos depremi  {{Akademik dergi kaynağı|başlık=Earthquake sou...
# 6    1481 Rodos depremi  {{Akademik dergi kaynağı|başlık=Historical and...
# 8    1481 Rodos depremi  {{Akademik dergi kaynağı|başlık=New approaches...
#
#                        journal                           sim_id     date  \
# 1  Planetary and Space Science  sim_planetary-and-space-science  2012-12
# 2                  Chemosphere                  sim_chemosphere  1999-12
# 5               Tectonophysics               sim_tectonophysics  2012-04
# 6               Marine Geology               sim_marine-geology  2014-08
# 8                  Nat Hazards                  sim_nat-hazards  2010-12
#
#    year  volume issue                                              title  \
# 1  2012      73                                     Density of asteroids
# 2  1999      39    15  Partial solubility parameters of chlorobenzene...
# 5  2012  536537        Earthquake source parameters along the Helleni...
# 6  2014     354        Historical and pre-historical tsunamis in the ...
# 8  2010      63     1  New approaches in assessment of tsunami deposi...
#
#    page url                            doi
# 1    98          10.1016/j.pss.2012.03.009
# 2  2607      10.1016/s0045-6535(99)00173-3
# 5    61        10.1016/j.tecto.2012.02.019
# 6    81       10.1016/j.margeo.2014.04.014
# 8   181          10.1007/s11069-010-9692-5

# %%
df_wo_url_wo_doi = df_wo_url[df_wo_url['doi'] == ""]
print("There are " + str(df_wo_url_wo_doi.shape[0]) + " without existing urls out of " + str(df_wo_url.shape[0]))
df_wo_url_wo_doi.head()
# Out:
# There are 2512 without existing urls out of 8153
#                  a                                                  c  \
# 21       3-Oktanon  {{Akademik dergi kaynağı |başlık= Freshly Dist...
# 30  5-HT-Reseptörü  {{Akademik dergi kaynağı|başlık=International ...
# 31  5-HT-Reseptörü  {{Akademik dergi kaynağı|url=|başlık=The molec...
# 32  5-HT-Reseptörü  {{Akademik dergi kaynağı|yazar=Ramadan NM, Skl...
# 36  5-HT-Reseptörü  {{Akademik dergi kaynağı|url=|başlık=Appetite ...
#
#                  journal                    sim_id  date  year volume issue  \
# 21       Z Naturforsch C       sim_z-naturforsch-c  1978  1978     33   1-2
# 30         Pharmacol Rev         sim_pharmacol-rev  1994  1994     46     2
# 31       Biol Psychiatry       sim_biol-psychiatry  1998  1998     44    11
# 32           Cephalalgia           sim_cephalalgia  2003  2003     23     8
# 36  Trends Pharmacol Sci  sim_trends-pharmacol-sci  1997  1997     18     1
#
#                                                 title  page url doi
# 21  Freshly Distilled Oil of the Leaves of Rasmari...
# 30  International Union of Pharmacology classifica...   157
# 31  The molecular biology of serotonin receptors: ...  1128
# 32  5-HT1F receptor agonists in acute migraine tre...   776
# 36  Appetite suppression by commonly used drugs de...    21

# %% [markdown]
# ### Citations with Existing Urls
# - don't need to work with them

# %%
# df_w_url = parsed_citations_df[parsed_citations_df['url'] != ""]
# print("There are " + str(df_w_url.shape[0]) + " without existing urls out of " + str(parsed_citations_df.shape[0]))
# df_w_url.head()

# %% [markdown]
# ### Filter Citations Not in the SIM collections

# %% [markdown]
# #### Load info about SIM collections

# %%
# Load SIM information processed by SIM Metadata Parsing.ipynb
sim_info = pd.read_csv("SIM_info.csv")
sim_info.head()
# Out:
#                          PubIssueID                         Title NA Gaps  \
# 0              sim-anatomia-clinica              Anatomia Clinica     NaN
# 1                             sim_-                       The - -     NaN
# 2               sim_1001-home-ideas               1001 Home Ideas     NaN
# 3                   sim_102-monitor                   102 Monitor     NaN
# 4  sim_20th-century-british-history  20th Century British History     NaN
#
#    First Volume  Last Volume
# 0        1978.0       1981.0
# 1        1826.0       1826.0
# 2        1986.0       1991.0
# 3        1975.0       1981.0
# 4        1990.0       1994.0

# %%
 # Limit to citations with the exact sim_id match
df_wo_url_in_sim = pd.merge(left=df_wo_url, right=sim_info, how="inner", 
                  left_on="sim_id", right_on="PubIssueID")
print("Number of Citations without URL in SIM : " + str(df_wo_url_in_sim.shape[0]))
df_wo_url_in_sim.head()
# Out:
# Number of Citations without URL in SIM : 2634
#                                          a  \
# 0                              12 Victoria
# 1  Uzay Araştırma ve Teknolojisi Enstitüsü
# 2                             Azas Platosu
# 3                     1,3,5-Triklorobenzen
# 4                                 Orbitrap
#
#                                                    c  \
# 0  {{Akademik dergi kaynağı\n | ad1    = B.\n | s...
# 1  {{Akademik dergi kaynağı|başlık=Results of TV ...
# 2  {{Akademik dergi kaynağı|soyadı1=Komatsu|ad1=G...
# 3  {{Akademik dergi kaynağı|soyadı=Jaw|ad=Ching-G...
# 4  {{Akademik dergi kaynağı|başlık=Identification...
#
#                        journal                           sim_id     date  \
# 0  Planetary and Space Science  sim_planetary-and-space-science  2012-12
# 1  Planetary and Space Science  sim_planetary-and-space-science     1991
# 2  Planetary and Space Science  sim_planetary-and-space-science  2004-01
# 3                  Chemosphere                  sim_chemosphere  1999-12
# 4                  Chemosphere                  sim_chemosphere  2014-07
#
#    year volume issue                                              title  page  \
# 0  2012     73                                     Density of asteroids    98
# 1  1991     39   1–2  Results of TV imaging of phobos (experiment VS...   281
# 2  2004     52   1-3  Interior layered deposits of Valles Marineris,...   167
# 3  1999     39    15  Partial solubility parameters of chlorobenzene...  2607
# 4  2014    107        Identification of phase II pharmaceutical meta...    65
#
#   url                                doi                       PubIssueID  \
# 0              10.1016/j.pss.2012.03.009  sim_planetary-and-space-science
# 1           10.1016/0032-0633(91)90150-9  sim_planetary-and-space-science
# 2              10.1016/j.pss.2003.08.003  sim_planetary-and-space-science
# 3          10.1016/s0045-6535(99)00173-3                  sim_chemosphere
# 4      10.1016/j.chemosphere.2014.03.021                  sim_chemosphere
#
#                          Title NA Gaps  First Volume  Last Volume
# 0  Planetary and Space Science     NaN        1959.0       2002.0
# 1  Planetary and Space Science     NaN        1959.0       2002.0
# 2  Planetary and Space Science     NaN        1959.0       2002.0
# 3                  Chemosphere     NaN        1972.0       2003.0
# 4                  Chemosphere     NaN        1972.0       2003.0

# %%
 # Limit to citations with the exact sim_id match
df_wo_url_wo_doi_in_sim = pd.merge(left=df_wo_url_wo_doi, right=sim_info, how="inner", 
                  left_on="sim_id", right_on="PubIssueID")
print("Number of Citations without URL in SIM : " + str(df_wo_url_wo_doi_in_sim.shape[0]))
df_wo_url_wo_doi_in_sim.head()
# Out:
# Number of Citations without URL in SIM : 642
#                           a  \
# 0            5-HT-Reseptörü
# 1  AIDS Farkındalık Haftası
# 2               Akran grubu
# 3  Balilla-sınıfı denizaltı
# 4               Pikrik asit
#
#                                                    c  \
# 0  {{Akademik dergi kaynağı|yazar=Ramadan NM, Skl...
# 1  {{Akademik dergi kaynağı|başlık=Update / Mise ...
# 2  {{Akademik dergi kaynağı|başlık=Early adolesce...
# 3  {{Akademik dergi kaynağı|başlık=Question 12/88...
# 4  {{Akademik dergi kaynağı|soyadı1=Brown|ad1=Dav...
#
#                              journal                                 sim_id  \
# 0                        Cephalalgia                        sim_cephalalgia
# 1  Canadian Journal of Public Health  sim_canadian-journal-of-public-health
# 2                        Adolescence                        sim_adolescence
# 3              Warship International              sim_warship-international
# 4              Warship International              sim_warship-international
#
#       date  year volume issue  \
# 0     2003  2003     23     8
# 1  2002-01  2002     93     5
# 2     1976  1976     11
# 3     1989  1989            1
# 4     2001  2001            1
#
#                                                title page url doi  \
# 0  5-HT1F receptor agonists in acute migraine tre...  776
# 1                               Update / Mise à jour
# 2  Early adolescence and its conflict: Group iden...  261
# 3                                     Question 12/88   95
# 4               Ammunition Explosions in World War I   58
#
#                               PubIssueID                              Title  \
# 0                        sim_cephalalgia                        Cephalalgia
# 1  sim_canadian-journal-of-public-health  Canadian Journal of Public Health
# 2                        sim_adolescence                        Adolescence
# 3              sim_warship-international              Warship International
# 4              sim_warship-international              Warship International
#
#   NA Gaps  First Volume  Last Volume
# 0     NaN        1989.0       2004.0
# 1     NaN        1913.0       2014.0
# 2     NaN        1966.0       2009.0
# 3     NaN        1976.0       1996.0
# 4     NaN        1976.0       1996.0

# %%
#  # Limit to citations with the exact sim_id match
# df_w_url_in_sim = pd.merge(left=df_w_url, right=sim_info, how="inner", 
#                   left_on="sim_id", right_on="PubIssueID")
# print("Number of Citations with URL in SIM : " + str(df_w_url_in_sim.shape[0]))
# df_w_url_in_sim.head()

# %%
# # Limit to citations with the exact sim_id match
# df_in_sim = pd.merge(left = parsed_citations_df, right=sim_info, how="inner", 
#                   left_on="sim_id", right_on="PubIssueID")
# print("Number of Citations in SIM : " + str(df_in_sim.shape[0]))
# df_in_sim.head()

# %% [markdown]
# #### Filter out years that are not within the range of collection

# %%
# Filter out the journals of years that are not within the range of collection
def filter_year_range(row):
    year = row['year']
    
    first = row['First Volume']
    last = row['Last Volume']
    gaps = row['NA Gaps']
    if first != np.nan and last != np.nan:
        if year > first and year < last:
            if gaps != np.nan and gaps != "":
                gaps = str(gaps)
                gaps_list = gaps.split(";")
                for gap in gaps_list:
                    if gap.strip() == str(year):
                        return False
                return True
            return True
    return False
#     first = row['First Volume']
#     last = row['Last Volume']
#     if first != np.nan and last != np.nan:
#         if year > first and year < last:
#             return True
#     return False

# %%
df_wo_url_in_sim["within_yr_range"] = df_wo_url_in_sim.apply(filter_year_range, axis = 1)
df_wo_url_in_sim_yr_range = df_wo_url_in_sim[df_wo_url_in_sim["within_yr_range"]]
df_wo_url_in_sim_yr_range = df_wo_url_in_sim_yr_range.drop(columns = ['within_yr_range'])
df_wo_url_in_sim_yr_range = df_wo_url_in_sim_yr_range.reset_index(drop = True)
df_wo_url_in_sim_yr_range.head()
# Out:
#                                          a  \
# 0  Uzay Araştırma ve Teknolojisi Enstitüsü
# 1                     1,3,5-Triklorobenzen
# 2                                İz fosili
# 3                         1900’de Arjantin
# 4                           5-HT-Reseptörü
#
#                                                    c  \
# 0  {{Akademik dergi kaynağı|başlık=Results of TV ...
# 1  {{Akademik dergi kaynağı|soyadı=Jaw|ad=Ching-G...
# 2  {{akademik dergi kaynağı\n | yazar = Seilacher...
# 3  {{Akademik dergi kaynağı |başlık=ARGENTINA. Re...
# 4  {{Akademik dergi kaynağı|yazar=Ramadan NM, Skl...
#
#                        journal                           sim_id     date  \
# 0  Planetary and Space Science  sim_planetary-and-space-science     1991
# 1                  Chemosphere                  sim_chemosphere  1999-12
# 2               Marine Geology               sim_marine-geology     1967
# 3        Public Health Reports        sim_public-health-reports  1900-06
# 4                  Cephalalgia                  sim_cephalalgia     2003
#
#    year volume issue                                              title  page  \
# 0  1991     39   1–2  Results of TV imaging of phobos (experiment VS...   281
# 1  1999     39    15  Partial solubility parameters of chlorobenzene...  2607
# 2  1967      5   5–6                        Bathymetry of trace fossils   413
# 3  1900     15    24      ARGENTINA. Republic declared free from plague  1504
# 4  2003     23     8  5-HT1F receptor agonists in acute migraine tre...   776
#
#   url                            doi                       PubIssueID  \
# 0       10.1016/0032-0633(91)90150-9  sim_planetary-and-space-science
# 1      10.1016/s0045-6535(99)00173-3                  sim_chemosphere
# 2       10.1016/0025-3227(67)90051-5               sim_marine-geology
# 3                           41455481        sim_public-health-reports
# 4                                                     sim_cephalalgia
#
#                          Title NA Gaps  First Volume  Last Volume
# 0  Planetary and Space Science     NaN        1959.0       2002.0
# 1                  Chemosphere     NaN        1972.0       2003.0
# 2               Marine Geology     NaN        1964.0       2000.0
# 3        Public Health Reports     NaN        1878.0       2015.0
# 4                  Cephalalgia     NaN        1989.0       2004.0

# %%
print("Number of Citations without URL in SIM with range of collection years: " + 
      str(df_wo_url_in_sim_yr_range.shape[0]))
# Out:
# Number of Citations without URL in SIM with range of collection years: 1554

# %%
df_wo_url_wo_doi_in_sim["within_yr_range"] = df_wo_url_wo_doi_in_sim.apply(filter_year_range, axis = 1)
df_wo_url_wo_doi_in_sim_yr_range = df_wo_url_wo_doi_in_sim[df_wo_url_in_sim["within_yr_range"]]
df_wo_url_wo_doi_in_sim_yr_range = df_wo_url_wo_doi_in_sim_yr_range.drop(columns = ['within_yr_range'])
df_wo_url_wo_doi_in_sim_yr_range = df_wo_url_wo_doi_in_sim_yr_range.reset_index(drop = True)
df_wo_url_wo_doi_in_sim_yr_range.head()
# Out:
# /Users/xinyuechen/.pyenv/versions/3.7.5/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                             a  \
# 0    AIDS Farkındalık Haftası
# 1    Balilla-sınıfı denizaltı
# 2               Asar-ı Tevfik
# 3               Asar-ı Tevfik
# 4  Bismarck'ın son muharebesi
#
#                                                    c  \
# 0  {{Akademik dergi kaynağı|başlık=Update / Mise ...
# 1  {{Akademik dergi kaynağı|başlık=Question 12/88...
# 2  {{Akademik dergi kaynağı\n  |soyadı1=Caruana\n...
# 3  {{Akademik dergi kaynağı\n  |soyadı=Sturton\n ...
# 4  {{Akademik dergi kaynağı|soyadı1=Garzke|ad1= W...
#
#                              journal                                 sim_id  \
# 0  Canadian Journal of Public Health  sim_canadian-journal-of-public-health
# 1              Warship International              sim_warship-international
# 2              Warship International              sim_warship-international
# 3              Warship International              sim_warship-international
# 4              Warship International              sim_warship-international
#
#       date  year volume issue  \
# 0  2002-01  2002     93     5
# 1     1989  1989            1
# 2     2007  2007            4
# 3              0     57     2
# 4     1994  1994            2
#
#                                                title page url doi  \
# 0                               Update / Mise à jour
# 1                                     Question 12/88   95
# 2  Question 38/43: Loss of Ottoman Gunboat ''Inti...  326
# 3  Through British Eyes: Constantinople Dockyard,...
# 4                    The ''Bismarck'''s Final Battle  158
#
#                               PubIssueID                              Title  \
# 0  sim_canadian-journal-of-public-health  Canadian Journal of Public Health
# 1              sim_warship-international              Warship International
# 2              sim_warship-international              Warship International
# 3              sim_warship-international              Warship International
# 4              sim_warship-international              Warship International
#
#   NA Gaps  First Volume  Last Volume
# 0     NaN        1913.0       2014.0
# 1     NaN        1976.0       1996.0
# 2     NaN        1976.0       1996.0
# 3     NaN        1976.0       1996.0
# 4     NaN        1976.0       1996.0

# %%
print("Number of Citations without URL without doi in SIM with range of collection years: " + 
      str(df_wo_url_wo_doi_in_sim_yr_range.shape[0]))
# Out:
# Number of Citations without URL without doi in SIM with range of collection years: 458

# %%
df_possible_cite = df_wo_url_in_sim_yr_range[(df_wo_url_in_sim_yr_range["sim_id"] != "") &
                                            (df_wo_url_in_sim_yr_range["year"] != "") & 
                                            (df_wo_url_in_sim_yr_range["volume"] != "") & 
                                            (df_wo_url_in_sim_yr_range["page"] != "")]
print("Number of Citations without URL in SIM with range of collection years, has year, volume, page: " + 
      str(df_possible_cite.shape[0]))
df_possible_cite.head()
# Out:
# Number of Citations without URL in SIM with range of collection years, has year, volume, page: 1433
#                                          a  \
# 0  Uzay Araştırma ve Teknolojisi Enstitüsü
# 1                     1,3,5-Triklorobenzen
# 2                                İz fosili
# 3                         1900’de Arjantin
# 4                           5-HT-Reseptörü
#
#                                                    c  \
# 0  {{Akademik dergi kaynağı|başlık=Results of TV ...
# 1  {{Akademik dergi kaynağı|soyadı=Jaw|ad=Ching-G...
# 2  {{akademik dergi kaynağı\n | yazar = Seilacher...
# 3  {{Akademik dergi kaynağı |başlık=ARGENTINA. Re...
# 4  {{Akademik dergi kaynağı|yazar=Ramadan NM, Skl...
#
#                        journal                           sim_id     date  \
# 0  Planetary and Space Science  sim_planetary-and-space-science     1991
# 1                  Chemosphere                  sim_chemosphere  1999-12
# 2               Marine Geology               sim_marine-geology     1967
# 3        Public Health Reports        sim_public-health-reports  1900-06
# 4                  Cephalalgia                  sim_cephalalgia     2003
#
#    year volume issue                                              title  page  \
# 0  1991     39   1–2  Results of TV imaging of phobos (experiment VS...   281
# 1  1999     39    15  Partial solubility parameters of chlorobenzene...  2607
# 2  1967      5   5–6                        Bathymetry of trace fossils   413
# 3  1900     15    24      ARGENTINA. Republic declared free from plague  1504
# 4  2003     23     8  5-HT1F receptor agonists in acute migraine tre...   776
#
#   url                            doi                       PubIssueID  \
# 0       10.1016/0032-0633(91)90150-9  sim_planetary-and-space-science
# 1      10.1016/s0045-6535(99)00173-3                  sim_chemosphere
# 2       10.1016/0025-3227(67)90051-5               sim_marine-geology
# 3                           41455481        sim_public-health-reports
# 4                                                     sim_cephalalgia
#
#                          Title NA Gaps  First Volume  Last Volume
# 0  Planetary and Space Science     NaN        1959.0       2002.0
# 1                  Chemosphere     NaN        1972.0       2003.0
# 2               Marine Geology     NaN        1964.0       2000.0
# 3        Public Health Reports     NaN        1878.0       2015.0
# 4                  Cephalalgia     NaN        1989.0       2004.0

# %%
list(df_possible_cite['c'])[0:5]
# Out:
# ['{{Akademik dergi kaynağı|başlık=Results of TV imaging of phobos (experiment VSK-FREGAT)|yazarlar=Avanesov|sayı=1–2|sayfalar=281-295|çalışma=Planetary and Space Science|yayıncı=Elsevier|yıl=1991|cilt=39|pmid=11538495|doi=10.1016/0032-0633(91)90150-9}}',
#  '{{Akademik dergi kaynağı|soyadı=Jaw|ad=Ching-Guang|soyadı2=Chen|ad2=I-Ming|soyadı3=Yen|ad3=Jui-Hung|soyadı4=Wang|ad4=Yei-Shung|tarih=Aralık 1999|başlık=Partial solubility parameters of chlorobenzene and chlorophenol compounds at equilibrium distribution in two immiscible phases|dergi=Chemosphere|cilt=39|sayı=15|sayfalar=2607-2620|doi=10.1016/s0045-6535(99)00173-3|issn=0045-6535}}',
#  '{{akademik dergi kaynağı\n | yazar = Seilacher, D.\n |yıl= 1967\n | başlık = Bathymetry of trace fossils\n | dergi = Marine Geology\n | cilt = 5\n | sayı = 5–6\n |doi= 10.1016/0025-3227(67)90051-5\n | sayfalar =413-428|bibcode= 1967MGeol...5..413S\n }}',
#  '{{Akademik dergi kaynağı |başlık=ARGENTINA. Republic declared free from plague |author=John Hay |dergi=Public Health Reports  |cilt=15 |sayı=24 |tarih=15 Haziran 1900 |sayfa=1504 |jstor=41455481}}',
#  '{{Akademik dergi kaynağı|yazar=Ramadan NM, Skljarevski V, Phebus LA, Johnson KW|başlık=5-HT1F receptor agonists in acute migraine treatment: a hypothesis|dergi=Cephalalgia|cilt=23|sayı=8|sayfalar=776-785|yıl=2003|ay=Ekim|pmid=14510923|doi=|url=}}']

# %%
df_possible_cite_wo_doi = df_wo_url_wo_doi_in_sim_yr_range[(df_wo_url_wo_doi_in_sim_yr_range["sim_id"] != "") &
                                            (df_wo_url_wo_doi_in_sim_yr_range["year"] != "") & 
                                            (df_wo_url_wo_doi_in_sim_yr_range["volume"] != "") & 
                                            (df_wo_url_wo_doi_in_sim_yr_range["page"] != "")]
print("Number of Citations without URL in SIM with range of collection years, has year, volume, page: " + 
      str(df_possible_cite_wo_doi.shape[0]))
df_possible_cite_wo_doi.head()
# Out:
# Number of Citations without URL in SIM with range of collection years, has year, volume, page: 369
#                    a                                                  c  \
# 5  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus in Honor...
# 6  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus in Honor...
# 7  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus Honoring...
# 8  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus on Appli...
# 9         Béla Paizs  {{Akademik dergi kaynağı|başlık=Focus in Honor...
#
#                                              journal  \
# 5  Journal of the American Society for Mass Spect...
# 6  Journal of the American Society for Mass Spect...
# 7  Journal of the American Society for Mass Spect...
# 8  Journal of the American Society for Mass Spect...
# 9  Journal of the American Society for Mass Spect...
#
#                                               sim_id     date  year volume  \
# 5  sim_journal-of-the-american-society-for-mass-s...  2011-06  2011     22
# 6  sim_journal-of-the-american-society-for-mass-s...  2013-09  2013     24
# 7  sim_journal-of-the-american-society-for-mass-s...  2017-07  2017     28
# 8  sim_journal-of-the-american-society-for-mass-s...  2018-07  2018     29
# 9  sim_journal-of-the-american-society-for-mass-s...     2012  2012     23
#
#   issue                                              title  page url doi  \
# 5     8  Focus in Honor of David Muddiman, Recipient of...  1299
# 6    11  Focus in Honor of Josh Coon, Recipient of the ...  1621
# 7     9  Focus Honoring Dr. Kristina "Kicki" Håkansson,...  1739
# 8     9  Focus on Application of Photons and Radicals f...  1757
# 9     4  Focus in Honor of Béla Paizs, Recipient of the...   573
#
#                                           PubIssueID  \
# 5  sim_journal-of-the-american-society-for-mass-s...
# 6  sim_journal-of-the-american-society-for-mass-s...
# 7  sim_journal-of-the-american-society-for-mass-s...
# 8  sim_journal-of-the-american-society-for-mass-s...
# 9  sim_journal-of-the-american-society-for-mass-s...
#
#                                                Title NA Gaps  First Volume  \
# 5  Journal of the American Society for Mass Spect...     NaN        1990.0
# 6  Journal of the American Society for Mass Spect...     NaN        1990.0
# 7  Journal of the American Society for Mass Spect...     NaN        1990.0
# 8  Journal of the American Society for Mass Spect...     NaN        1990.0
# 9  Journal of the American Society for Mass Spect...     NaN        1990.0
#
#    Last Volume
# 5       1993.0
# 6       1993.0
# 7       1993.0
# 8       1993.0
# 9       1993.0

# %%
# df_in_sim["within_yr_range"] = df_in_sim.apply(filter_year_range, axis = 1)
# df_in_sim_yr_range = df_in_sim[df_in_sim["within_yr_range"]]
# df_in_sim_yr_range = df_in_sim_yr_range.drop(columns = ['within_yr_range'])
# df_in_sim_yr_range = df_in_sim_yr_range.reset_index(drop = True)
# df_in_sim_yr_range.head()

# %%
# print("Number of Citations in SIM with range of collection years: " + 
#       str(df_in_sim_yr_range.shape[0]))

# %% [markdown]
# ### Out of curiosity

# %%
name_not_match = df_possible_cite_wo_doi[df_possible_cite_wo_doi['journal'] != df_possible_cite_wo_doi['Title']]
print(name_not_match.shape)
name_not_match.head()
# Out:
# (48, 17)
#                                                      a  \
# 29                                 Harden M. McConnell
# 70                                  Gece yeme sendromu
# 89   Güneş Sistemi'ndeki kütleçekimsel yuvarlak nes...
# 90   Güneş Sistemi'ndeki kütleçekimsel yuvarlak nes...
# 133                                      Kemerli burun
#
#                                                      c  \
# 29   {{Akademik dergi kaynağı|başlık=PEOPLE|sayı=38...
# 70   {{Akademik dergi kaynağı|url=|başlık=Neuroendo...
# 89   {{Akademik dergi kaynağı|başlık=The Origin and...
# 90   {{Akademik dergi kaynağı|başlık=The size, dens...
# 133  {{Akademik dergi kaynağı|başlık=The Common Sen...
#
#                                               journal  \
# 29                         Chemical  Engineering News
# 70   Journal of Clinical Endocrinology and Metabolism
# 89                              Astronomy  Geophysics
# 90                               Astronomical Journal
# 133                               Law  Social Inquiry
#
#                                                 sim_id  date  year volume  \
# 29                       sim_chemical-engineering-news  1968  1968     46
# 70   sim_journal-of-clinical-endocrinology-and-meta...  2005  2005      9
# 89                            sim_astronomy-geophysics  2000  2000     41
# 90                            sim_astronomical-journal  2009  2009    139
# 133                             sim_law-social-inquiry  2006  2006     31
#
#     issue                                              title  page url doi  \
# 29     38                                             PEOPLE    36
# 70     11  Neuroendocrine profiles associated with energy...  6214
# 89      1       The Origin and Evolution of the Solar System  1.12
# 90      6  The size, density, and formation of the Orcus-...  2700
# 133     2  The Common Sense of Anti-Indian Racism: Reacti...   313
#
#                                             PubIssueID  \
# 29                       sim_chemical-engineering-news
# 70   sim_journal-of-clinical-endocrinology-and-meta...
# 89                            sim_astronomy-geophysics
# 90                            sim_astronomical-journal
# 133                             sim_law-social-inquiry
#
#                                                  Title NA Gaps  First Volume  \
# 29                         Chemical & Engineering News     NaN        1923.0
# 70   The Journal of Clinical Endocrinology and Meta...     NaN        1941.0
# 89                              Astronomy & Geophysics     NaN        1980.0
# 90                            The Astronomical Journal     NaN        1849.0
# 133                               Law & Social Inquiry     NaN        1982.0
#
#      Last Volume
# 29        2014.0
# 70        1977.0
# 89        1996.0
# 90        1994.0
# 133       2006.0

# %% [markdown]
# ## Work with Advanced Search

# %% [markdown]
# #### Concept (one case)

# %%
test_url_head = "https://archive.org/advancedsearch.php?q="
test_identifier = "sim_canadian-journal-of-public-health_2002"
test_url_tail = "&fl%5B%5D=identifier&callback=callback&save=yes&output=json"

# %%
test_url = test_url_head + test_identifier + test_url_tail
request = requests.get(test_url)
request.text
# Out:
# 'callback({"responseHeader":{"status":0,"QTime":146,"params":{"query":"(( ( (title:\\"sim_canadian-journal-of-public-health_2002\\"^100 OR salients:\\"sim_canadian-journal-of-public-health_2002\\"^50 OR subject:\\"sim_canadian-journal-of-public-health_2002\\"^25 OR description:\\"sim_canadian-journal-of-public-health_2002\\"^15 OR collection:\\"sim_canadian-journal-of-public-health_2002\\"^10 OR language:\\"sim_canadian-journal-of-public-health_2002\\"^10 OR text:\\"sim_canadian-journal-of-public-health_2002\\"^1) ) AND !collection:(podcasts OR radio OR uspto))^2 OR ( ( (title:\\"sim_canadian-journal-of-public-health_2002\\"^100 OR salients:\\"sim_canadian-journal-of-public-health_2002\\"^50 OR subject:\\"sim_canadian-journal-of-public-health_2002\\"^25 OR description:\\"sim_canadian-journal-of-public-health_2002\\"^15 OR collection:\\"sim_canadian-journal-of-public-health_2002\\"^10 OR language:\\"sim_canadian-journal-of-public-health_2002\\"^10 OR text:\\"sim_canadian-journal-of-public-health_2002\\"^1) ) AND collection:(podcasts OR radio OR uspto))^0.5)","qin":"sim_canadian-journal-of-public-health_2002","fields":"identifier","wt":"json","json.wrf":"callback","start":0}},"response":{"numFound":1,"start":0,"docs":[{"_score":65.774864,"identifier":"sim_canadian-journal-of-public-health_2002_93_index"}]}})'

# %%
info = request.text[9:-1]
info
# Out:
# '{"responseHeader":{"status":0,"QTime":146,"params":{"query":"(( ( (title:\\"sim_canadian-journal-of-public-health_2002\\"^100 OR salients:\\"sim_canadian-journal-of-public-health_2002\\"^50 OR subject:\\"sim_canadian-journal-of-public-health_2002\\"^25 OR description:\\"sim_canadian-journal-of-public-health_2002\\"^15 OR collection:\\"sim_canadian-journal-of-public-health_2002\\"^10 OR language:\\"sim_canadian-journal-of-public-health_2002\\"^10 OR text:\\"sim_canadian-journal-of-public-health_2002\\"^1) ) AND !collection:(podcasts OR radio OR uspto))^2 OR ( ( (title:\\"sim_canadian-journal-of-public-health_2002\\"^100 OR salients:\\"sim_canadian-journal-of-public-health_2002\\"^50 OR subject:\\"sim_canadian-journal-of-public-health_2002\\"^25 OR description:\\"sim_canadian-journal-of-public-health_2002\\"^15 OR collection:\\"sim_canadian-journal-of-public-health_2002\\"^10 OR language:\\"sim_canadian-journal-of-public-health_2002\\"^10 OR text:\\"sim_canadian-journal-of-public-health_2002\\"^1) ) AND collection:(podcasts OR radio OR uspto))^0.5)","qin":"sim_canadian-journal-of-public-health_2002","fields":"identifier","wt":"json","json.wrf":"callback","start":0}},"response":{"numFound":1,"start":0,"docs":[{"_score":65.774864,"identifier":"sim_canadian-journal-of-public-health_2002_93_index"}]}}'

# %%
import json
response = json.loads(info)
response
# Out:
# {'responseHeader': {'status': 0,
#   'QTime': 146,
#   'params': {'query': '(( ( (title:"sim_canadian-journal-of-public-health_2002"^100 OR salients:"sim_canadian-journal-of-public-health_2002"^50 OR subject:"sim_canadian-journal-of-public-health_2002"^25 OR description:"sim_canadian-journal-of-public-health_2002"^15 OR collection:"sim_canadian-journal-of-public-health_2002"^10 OR language:"sim_canadian-journal-of-public-health_2002"^10 OR text:"sim_canadian-journal-of-public-health_2002"^1) ) AND !collection:(podcasts OR radio OR uspto))^2 OR ( ( (title:"sim_canadian-journal-of-public-health_2002"^100 OR salients:"sim_canadian-journal-of-public-health_2002"^50 OR subject:"sim_canadian-journal-of-public-health_2002"^25 OR description:"sim_canadian-journal-of-public-health_2002"^15 OR collection:"sim_canadian-journal-of-public-health_2002"^10 OR language:"sim_canadian-journal-of-public-health_2002"^10 OR text:"sim_canadian-journal-of-public-health_2002"^1) ) AND collection:(podcasts OR radio OR uspto))^0.5)',
#    'qin': 'sim_canadian-journal-of-public-health_2002',
#    'fields': 'identifier',
#    'wt': 'json',
#    'json.wrf': 'callback',
#    'start': 0}},
#  'response': {'numFound': 1,
#   'start': 0,
#   'docs': [{'_score': 65.774864,
#     'identifier': 'sim_canadian-journal-of-public-health_2002_93_index'}]}}

# %%
response['response']
# Out:
# {'numFound': 1,
#  'start': 0,
#  'docs': [{'_score': 65.774864,
#    'identifier': 'sim_canadian-journal-of-public-health_2002_93_index'}]}

# %%
response['response']['docs']
# Out:
# [{'_score': 65.774864,
#   'identifier': 'sim_canadian-journal-of-public-health_2002_93_index'}]

# %% [markdown]
# ### Generalize

# %%
def initialize_archive_session():
    with open('cookie.txt') as f:
        login_data_raw = f.read()
    
    login_data = json.loads(login_data_raw)
    
    session = requests.Session()
    
#     # Mount it for both http and https usage
#     adapter = TimeoutHTTPAdapter(timeout=10)
#     session.mount("https://", adapter)
#     session.mount("http://", adapter)
    
    # get login values through scraping
    login_url = "https://archive.org/account/login"
    res = session.get(login_url, timeout = 10)
    soup = BeautifulSoup(res.content, "html.parser")
    login_data['login'] = soup.find('input', attrs = {'name':'login'})['value']    
    
    # post cookie values to login 
    res = session.post(login_url, data = login_data, timeout = 10)
    
    return session, login_data

# %%
def perform_advanced_search(session, login_data, identifier):
    url_head = "https://archive.org/advancedsearch.php?q="
    url_tail = "&fl%5B%5D=identifier&sort%5B%5D=&sort%5B%5D=&sort%5B%5D=&rows=5000&page=1&output=json&callback=callback&save=yes"
    
    url = url_head + identifier + url_tail
    
    try:
        request = session.get(url, data = login_data, timeout = 10)
        request.raise_for_status()
        
        response = request.text[9:-1]
        response_json = json.loads(response)['response']

        nums = response_json['numFound']

        # if nothing is found, return empty string
        if nums == 0: 
            return ""

        # if more than one thing is found, return 
        result = dict()
        response_list = response_json['docs']
        for item in response_list:
            temp_id = item['identifier']
            temp_score = item['_score']
            result[temp_id] = temp_score

        return result
    except requests.exceptions.HTTPError as errh:
        print ("Http Error:",errh)
    except requests.exceptions.ConnectionError as errc:
        print ("Error Connecting:",errc)
    except requests.exceptions.Timeout as errt:
        print ("Timeout Error:",errt)
    except requests.exceptions.RequestException as err:
        print ("OOps: Something Else",err)
    
    return ""

# %%
# For example, there can be no response
session, login_data = initialize_archive_session()
perform_advanced_search(session, login_data, "sim_marine-geology")
# Out:
# ''

# %%
# For example, there can be multiple response
perform_advanced_search(session, login_data, "sim_canadian-journal-of-public-health_1994_85")
# Out:
# {'sim_canadian-journal-of-public-health_november-december-1993_84_6': 1275.6439,
#  'sim_canadian-journal-of-public-health_january-february-1994_85_1': 1268.1522,
#  'sim_canadian-journal-of-public-health_1994_85_index': 79.35465}

# %% [markdown]
# Directly Using URL generation, something like https://archive.org/details/sim_bioscience_1996_46_index would be deemed bad when in fact, it is just in a different string format

# %%
# For example, there can be a lot of responses
ex_multiple = perform_advanced_search(session, login_data, "sim_bioscience_1996_46")
ex_multiple
# Out:
# {'sim_bioscience_1996-05_46_5': 1442.0604,
#  'sim_bioscience_1996-02_46_2': 1438.8639,
#  'sim_bioscience_1996-01_46_1': 1432.8804,
#  'sim_bioscience_1996-11_46_10': 1429.0781,
#  'sim_bioscience_1996-09_46_8': 1423.1581,
#  'sim_bioscience_1996-10_46_9': 1420.214,
#  'sim_bioscience_1996-04_46_4': 1418.4635,
#  'sim_bioscience_july-august-1996_46_7': 1414.2814,
#  'sim_bioscience_1996-06_46_6': 1412.6345,
#  'sim_bioscience_1996-03_46_3': 1408.5902,
#  'sim_bioscience_january-december-1996_46_index': 1359.7362,
#  'sim_bioscience_1996-12_46_11': 1358.7174,
#  'sim_bioscience_1995-12_45_11': 1255.2961,
#  'sim_bioscience_january-december-1997_47_index': 1246.396}

# %%
def find_best_identifier_of_multiple(d):
    keys = list(d.keys())
    vals = list(d.values())
    index_of_max = vals.index(max(vals))
    return keys[index_of_max]

# %%
find_best_identifier_of_multiple(ex_multiple)
# Out:
# 'sim_bioscience_1996-05_46_5'

# %% [markdown]
# ### Generate Identifiers

# %%
### Different functions for generating ids
def generate_id_journal_year(cite_info):
    identifier = cite_info['sim_id'] 
    if cite_info['year'] != 0:
        identifier = identifier + "_" + str(cite_info['year'])
    return identifier

def generate_id_journal_date(cite_info):
    identifier = cite_info['sim_id'] 
    if cite_info['date'] != "":
        identifier = identifier + "_" + str(cite_info['date'])
    return identifier

    
def generate_id_journal_year_volume(cite_info):
    identifier = generate_id_journal_year(cite_info)
    if cite_info['volume'] != "":
        identifier = identifier + "_" + cite_info['volume']
    return identifier

def generate_id_journal_date_volume(cite_info):
    identifier = generate_id_journal_date(cite_info)
    if cite_info['volume'] != "":
        identifier = identifier + "_" + cite_info['volume']
    return identifier


def generate_id_journal_year_volume_issue(cite_info):
    identifier = generate_id_journal_year_volume(cite_info)
    if cite_info['issue'] != "":
        identifier = identifier + "_" + cite_info['issue']
    return identifier

def generate_id_journal_date_volume_issue(cite_info):
    identifier = generate_id_journal_date_volume(cite_info)
    if cite_info['issue'] != "":
        identifier = identifier + "_" + cite_info['issue']
    return identifier

# %%
df_possible_cite.head()
# Out:
#                                          a  \
# 0  Uzay Araştırma ve Teknolojisi Enstitüsü
# 1                     1,3,5-Triklorobenzen
# 2                                İz fosili
# 3                         1900’de Arjantin
# 4                           5-HT-Reseptörü
#
#                                                    c  \
# 0  {{Akademik dergi kaynağı|başlık=Results of TV ...
# 1  {{Akademik dergi kaynağı|soyadı=Jaw|ad=Ching-G...
# 2  {{akademik dergi kaynağı\n | yazar = Seilacher...
# 3  {{Akademik dergi kaynağı |başlık=ARGENTINA. Re...
# 4  {{Akademik dergi kaynağı|yazar=Ramadan NM, Skl...
#
#                        journal                           sim_id     date  \
# 0  Planetary and Space Science  sim_planetary-and-space-science     1991
# 1                  Chemosphere                  sim_chemosphere  1999-12
# 2               Marine Geology               sim_marine-geology     1967
# 3        Public Health Reports        sim_public-health-reports  1900-06
# 4                  Cephalalgia                  sim_cephalalgia     2003
#
#    year volume issue                                              title  page  \
# 0  1991     39   1–2  Results of TV imaging of phobos (experiment VS...   281
# 1  1999     39    15  Partial solubility parameters of chlorobenzene...  2607
# 2  1967      5   5–6                        Bathymetry of trace fossils   413
# 3  1900     15    24      ARGENTINA. Republic declared free from plague  1504
# 4  2003     23     8  5-HT1F receptor agonists in acute migraine tre...   776
#
#   url                            doi                       PubIssueID  \
# 0       10.1016/0032-0633(91)90150-9  sim_planetary-and-space-science
# 1      10.1016/s0045-6535(99)00173-3                  sim_chemosphere
# 2       10.1016/0025-3227(67)90051-5               sim_marine-geology
# 3                           41455481        sim_public-health-reports
# 4                                                     sim_cephalalgia
#
#                          Title NA Gaps  First Volume  Last Volume
# 0  Planetary and Space Science     NaN        1959.0       2002.0
# 1                  Chemosphere     NaN        1972.0       2003.0
# 2               Marine Geology     NaN        1964.0       2000.0
# 3        Public Health Reports     NaN        1878.0       2015.0
# 4                  Cephalalgia     NaN        1989.0       2004.0

# %%
def generate_ids(cite_info):
    
    # check have minimum set of info
    has_2_yr = False
    has_3_yr = False
    has_4_yr = False
    has_2_date = False
    has_3_date = False
    has_4_date = False

    if cite_info["sim_id"] != "" and cite_info["volume"] != "":

        if cite_info['year'] != "":
            has_3_yr = True
            has_2_yr = True
            if cite_info["issue"]:
                has_4_yr = True
        if cite_info['date'] != "":
            has_3_date = True
            has_2_date = True
            if cite_info["issue"]:
                has_4_date = True
    
    gen_ids = []
    if has_2_date:
        gen_ids.append(generate_id_journal_date(cite_info))

    if has_2_yr:
        gen_ids.append(generate_id_journal_year(cite_info))

    if has_3_date: 
        gen_ids.append(generate_id_journal_date_volume(cite_info))

    if has_3_yr:
        gen_ids.append(generate_id_journal_year_volume(cite_info))

    if has_4_date:
        gen_ids.append(generate_id_journal_date_volume_issue(cite_info))

    if has_4_yr:
        gen_ids.append(generate_id_journal_year_volume_issue(cite_info))
        
    return gen_ids

# %%
# df_possible_cite['generated_ids'] = df_possible_cite.apply(generate_ids, axis = 1)
# df_possible_cite.head()

# %%
# df_possible_cite.loc[0, 'generated_ids']

# %% [markdown]
# ### Different Methods for finding identifier from generated identifiers

# %%
# def find_highest_score_from_generated_id(identifier):
#     result = perform_advanced_search(identifier)
#     if type(result) is str:
#         return result
#     else:
#         return find_best_identifier_of_multiple(result)

# %%
def find_close_match_from_cite_info(cite_info, search_result, verbose = False):
    id_list = list(search_result.keys())
#     identifier_list = identifier.split("_")

#     print(cite_info)
    
    close_matches = dict()
    for possible_id in id_list:
        possible_id_list = possible_id.split("_")
        
        
        if verbose: print(possible_id_list)
        
        if len(possible_id_list) < 4:
            continue;
        
        if cite_info["issue"] != "" and len(possible_id_list) >= 5:
            
            if verbose: print("longer than 5")
            
            # Check that it is sim
            if possible_id_list[0] == "sim":
                
                # Check that journal name matches
                if possible_id_list[1] == cite_info['sim_id'][4:]:
                    
                    # Check that year/date is within other case
                    if str(cite_info["year"]) in possible_id_list[2]:
                        
                        # Check that journal volume matches
                        if possible_id_list[3] == cite_info["volume"]:
                            
                            # Check that journal issue matches
                            if possible_id_list[4] == cite_info["issue"]:
                                close_matches[possible_id] = search_result[possible_id]
                                continue;
                                
                            if verbose: print("Not the right issue")
                            continue;
                            
                        if verbose: print("Not the right volume")
                        continue;
                        
                    if verbose: print("Not the right year")
                    continue;
                    
                if verbose: print("Possible id journal name not exact match")
                continue;
                
            if verbose: print("Possible id is not in sim")
            continue;
            
        if len(possible_id_list) == 4:
            
            if verbose: print("equal to 4")
            
            # Check that it is sim
            if possible_id_list[0] == "sim":
                
                # Check that journal name matches
                if possible_id_list[1] == cite_info['sim_id'][4:]:
                    
                    # Check that year/date is within other case
                    if str(cite_info["year"]) in possible_id_list[2]:
                        
                        # Check that journal volume matches
                        if possible_id_list[3] == cite_info["volume"]:
                            
                            close_matches[possible_id] = search_result[possible_id]
                            continue;
                            
                        if verbose: print("Not the right volume")
                        continue;
                        
                    if verbose: print("Not the right year")
                    continue;
                    
                if verbose: print("Possible id journal name not exact match")
                continue;
                            
            if verbose: print("Possible id is not in sim")
            continue;
            
    if verbose: 
        print('close matches: ')
        print(close_matches)
                    
    if not close_matches:
        return ""
    
    close_matches_keys = list(close_matches.keys())
    close_matches_values = list(close_matches.values())
    
    # if 1 close match, return it
    if len(close_matches_keys) == 1:
        return close_matches_keys[0]
    
    
    # if multiple, return the one with the highest score
    index_of_max = close_matches_values.index(max(close_matches_values))
    return close_matches_keys[index_of_max]

# %%
def generate_url_actual(identifier):
    return "https://archive.org/details/" + identifier

# %%
def find_actual_identifier(cite_info):
    # generate a id
    gen_id = generate_id_journal_year(cite_info)
            
    # initialize session
    session, login_data = initialize_archive_session()
            
    # find all entries with this journal name
    search_result = perform_advanced_search(session, login_data, gen_id)
            
    if search_result != "":

        # find close match on generated id
        real_id = find_close_match_from_cite_info(cite_info, search_result)
                
        if real_id != "":

            # new citation
            url = generate_url_actual(real_id)
            print("url: " + url)
            return url

        print("No close match exist for generated ids. The id is: ")
        return ""

    print("There's no search result for the id: " + gen_id)
    return ""

# %%
possible_url_wo_doi_lst = df_possible_cite_wo_doi.apply(find_actual_identifier, axis = 1)
# possible_url_wo_doi_lst
# Out:
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2011
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2013
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2017
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2018
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2012
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2004
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2006
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2013
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2013
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2013
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2011
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2011
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2011
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_1994
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2005
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2001
# There's no search result for the id: sim_journal-of-the-american-society-for-mass-spectrometry_2002
# There's no search result for the id: sim_scientific-american_1975
# There's no search result for the id: sim_scientific-american_2015
# There's no search result for the id: sim_scientific-american_2007
# There's no search result for the id: sim_scientific-american_1955
# There's no search result for the id: sim_scientific-american_1987
# There's no search result for the id: sim_chemical-engineering-news_1968
# No close match exist for ids.
# There's no search result for the id: sim_journal-of-the-american-oriental-society
# There's no search result for the id: sim_psychological-science_2000
# There's no search result for the id: sim_psychological-science_2000
# There's no search result for the id: sim_psychological-science_2004
# There's no search result for the id: sim_psychological-science_2008
# There's no search result for the id: sim_psychological-science_2014
# There's no search result for the id: sim_psychological-science_2008
# url: https://archive.org/details/sim_applied-cognitive-psychology_2010-02_24_2
# No close match exist for ids.
# url: https://archive.org/details/sim_applied-cognitive-psychology_2009-02_23_2
# url: https://archive.org/details/sim_applied-cognitive-psychology_2009-02_23_2
# url: https://archive.org/details/sim_applied-cognitive-psychology_2007-12_21_8
# url: https://archive.org/details/sim_applied-cognitive-psychology_2009-07_23_5
# url: https://archive.org/details/sim_applied-cognitive-psychology_2003-11_17_7
# url: https://archive.org/details/sim_applied-cognitive-psychology_2005-05_19_4
# url: https://archive.org/details/sim_applied-cognitive-psychology_2005-04_19_3
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# There's no search result for the id: sim_journal-of-experimental-psychology_1971
# There's no search result for the id: sim_journal-of-experimental-psychology_1962
# url: https://archive.org/details/sim_journal-of-experimental-psychology_2011-10_37_5
# There's no search result for the id: sim_psychology-and-aging_2010
# There's no search result for the id: sim_psychology-and-aging_1993
# There's no search result for the id: sim_psychology-and-aging_2010
# There's no search result for the id: sim_psychology-and-aging_2010
# There's no search result for the id: sim_canadian-journal-of-psychiatry_2009
# There's no search result for the id: sim_international-journal-of-eating-disorders_2008
# There's no search result for the id: sim_international-journal-of-eating-disorders_2006
# There's no search result for the id: sim_international-journal-of-eating-disorders_2001
# There's no search result for the id: sim_international-journal-of-obesity_1996
# There's no search result for the id: sim_international-journal-of-obesity_2009
# There's no search result for the id: sim_clinical-psychology-review_2012
# There's no search result for the id: sim_clinical-psychology-review_2007
# There's no search result for the id: sim_clinical-psychology-review_2007
# No close match exist for ids.
# There's no search result for the id: sim_journal-of-clinical-endocrinology-and-metabolism_2005
# There's no search result for the id: sim_journal-of-college-student-psychotherapy_2010
# There's no search result for the id: sim_psychological-bulletin_1995
# There's no search result for the id: sim_psychological-bulletin_1986
# There's no search result for the id: sim_psychological-bulletin_2016
# There's no search result for the id: sim_psychological-bulletin_2008
# There's no search result for the id: sim_psychological-bulletin_1992
# No close match exist for ids.
# There's no search result for the id: sim_behavioural-brain-research_2005
# There's no search result for the id: sim_psychological-review_1993
# There's no search result for the id: sim_psychological-review_1990
# There's no search result for the id: sim_psychological-review_1990
# There's no search result for the id: sim_psychological-review_1994
# There's no search result for the id: sim_psychological-review_2005
# There's no search result for the id: sim_psychological-review_2007
# There's no search result for the id: sim_psychological-review_1969
# There's no search result for the id: sim_psychological-review_1968
# url: https://archive.org/details/sim_psychonomic-science_1966-11-15_6_8
# url: https://archive.org/details/sim_psychonomic-science_1972-04-25_27_2
# There's no search result for the id: sim_astronomy-geophysics_2000
# There's no search result for the id: sim_astronomical-journal_2009
# url: https://archive.org/details/sim_science_1996-10-18_274_5286
# url: https://archive.org/details/sim_science_2006-03-10_311_5766
# url: https://archive.org/details/sim_science_1993-08-06_261_5122
# url: https://archive.org/details/sim_science_1989-12-15_246_4936
# url: https://archive.org/details/sim_science_2012-03-16_335_6074
# url: https://archive.org/details/sim_science_2009-12-18_326_5960
# url: https://archive.org/details/sim_science_2004-01-16_303_5656
# url: https://archive.org/details/sim_science_1994-11-11_266_5187
# url: https://archive.org/details/sim_science_2005-12-09_310_5754
# url: https://archive.org/details/sim_science_1964-10-30_146_3644
# url: https://archive.org/details/sim_science_1985-03-29_227_4694
# url: https://archive.org/details/sim_science_1981-12-18_214_4527
# url: https://archive.org/details/sim_science_2008-10-24_322_5901
# No close match exist for ids.
# url: https://archive.org/details/sim_science_2008-03-14_319_5869
# No close match exist for ids.
# url: https://archive.org/details/sim_science_2005-12-16_310_5755
# No close match exist for ids.
# url: https://archive.org/details/sim_science_2009-11-13_326_5955
# url: https://archive.org/details/sim_science_2011-11-25_334_6059
# No close match exist for ids.
# url: https://archive.org/details/sim_science_1995-08-11_269_5225
# url: https://archive.org/details/sim_science_1995-05-05_268_5211
# url: https://archive.org/details/sim_science_1996-04-19_272_5260
# url: https://archive.org/details/sim_science_1991-05-24_252_5009
# url: https://archive.org/details/sim_science_1971-02-19_171_3972
# url: https://archive.org/details/sim_science_1992-01-31_255_5044
# url: https://archive.org/details/sim_science_1996-03-15_271_5255
# url: https://archive.org/details/sim_science_1995-06-23_268_5218
# url: https://archive.org/details/sim_science_1994-05-27_264_5163
# No close match exist for ids.
# No close match exist for ids.
# There's no search result for the id: sim_victorian-periodicals-review_2004
# There's no search result for the id: sim_law-social-inquiry_2006
# url: https://archive.org/details/sim_nature-biotechnology_1999-10_17_10
# url: https://archive.org/details/sim_nature-biotechnology_2001-03_19_3
# There's no search result for the id: sim_nature-biotechnology_2018
# There's no search result for the id: sim_journal-of-personality-and-social-psychology_1993
# There's no search result for the id: sim_journal-of-personality-and-social-psychology_2003
# There's no search result for the id: sim_journal-of-personality-and-social-psychology_2001
# There's no search result for the id: sim_journal-of-personality-and-social-psychology_1996
# There's no search result for the id: sim_journal-of-personality-and-social-psychology_1987
# There's no search result for the id: sim_journal-of-personality-and-social-psychology_1995
# There's no search result for the id: sim_personality-and-individual-differences_2012
# There's no search result for the id: sim_personality-and-individual-differences_2009
# There's no search result for the id: sim_evolution-and-human-behavior_2002
# There's no search result for the id: sim_human-reproduction_2010
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# There's no search result for the id: sim_analytical-chemistry_2016
# There's no search result for the id: sim_analytical-chemistry_2017
# There's no search result for the id: sim_analytical-chemistry_2012
# url: https://archive.org/details/sim_annual-review-of-biochemistry_2012_81
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# There's no search result for the id: sim_environmental-history_2012
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# url: https://archive.org/details/sim_arethusa_fall-1980_13_2
# There's no search result for the id: sim_mycotaxon_1988
# There's no search result for the id: sim_mycotaxon_1999
# There's no search result for the id: sim_mycotaxon_1987
# There's no search result for the id: sim_south-african-journal-of-science_1924
# There's no search result for the id: sim_south-african-journal-of-science_1922
# There's no search result for the id: sim_design-issues_1999
# url: https://archive.org/details/sim_annals-of-the-new-york-academy-of-sciences_1976-10-28_280
# No close match exist for ids.
# url: https://archive.org/details/sim_brain_2009-05_132
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# No close match exist for ids.
# url: https://archive.org/details/sim_cortex_1990-12_26_4
# url: https://archive.org/details/sim_cortex_2008-06_44_6
# url: https://archive.org/details/sim_cortex_1997-12_33_4
# There's no search result for the id: sim_cortex_1982
# url: https://archive.org/details/sim_cancer-research_2001-07-15_61_14
# url: https://archive.org/details/sim_ethnohistory_winter-1989_36_1
# url: https://archive.org/details/sim_american-historical-review_1983-10_88_4
# There's no search result for the id: sim_middle-eastern-studies_2012
# There's no search result for the id: sim_middle-eastern-studies_2012
# There's no search result for the id: sim_middle-eastern-studies_2012
# There's no search result for the id: sim_middle-eastern-studies_2012
# url: https://archive.org/details/sim_journal-of-polymer-science-part-b-polymer-physics_2006-09-15_44_18
# url: https://archive.org/details/sim_journal-of-polymer-science-part-b-polymer-physics_2006-09-15_44_18
# url: https://archive.org/details/sim_journal-of-polymer-science-part-b-polymer-physics_2006-09-15_44_18
# There's no search result for the id: sim_macromolecules_1999
# There's no search result for the id: sim_macromolecules_1999
# There's no search result for the id: sim_macromolecules_1999
# There's no search result for the id: sim_macromolecules_2006
# There's no search result for the id: sim_macromolecules_2006
# There's no search result for the id: sim_journal-of-biological-chemistry_1944
# There's no search result for the id: sim_journal-of-biological-chemistry_1966
# There's no search result for the id: sim_journal-of-biological-chemistry
# There's no search result for the id: sim_journal-of-biological-chemistry_1923
# There's no search result for the id: sim_journal-of-biological-chemistry_1925
# No close match exist for ids.
# There's no search result for the id: sim_philosophical-review_19451946
# There's no search result for the id: sim_physiological-entomology_2016
# There's no search result for the id: sim_journal-of-agricultural-and-food-chemistry_2008
# There's no search result for the id: sim_journal-of-economic-entomology_2008
# There's no search result for the id: sim_family-practice_2014
# There's no search result for the id: sim_family-practice_2014
# There's no search result for the id: sim_family-practice_2014
# There's no search result for the id: sim_welding-journal_1999
# url: https://archive.org/details/sim_journal-of-the-canadian-chiropractic-association_1999-06_43_2
# There's no search result for the id: sim_contributions-to-mineralogy-and-petrology_1984
# url: https://archive.org/details/sim_annual-review-of-psychology_1996_47
# url: https://archive.org/details/sim_annual-review-of-psychology_2008_59
# url: https://archive.org/details/sim_annual-review-of-psychology_1998_49
# url: https://archive.org/details/sim_annual-review-of-psychology_1990_41
# There's no search result for the id: sim_psychonomic-bulletin-review_2000
# There's no search result for the id: sim_infant-mental-health-journal_2001
# There's no search result for the id: sim_journal-of-neuroendocrinology_1997
# There's no search result for the id: sim_neuroscience-letters_1984
# No close match exist for ids.
# There's no search result for the id: sim_journal-of-neurophysiology_2003
# There's no search result for the id: sim_radiation-measurements_2007
# There's no search result for the id: sim_lancet_2016
# There's no search result for the id: sim_commercial-motor_2000
# There's no search result for the id: sim_neuropsychologia_1996
# There's no search result for the id: sim_neuropsychologia_2000
# There's no search result for the id: sim_neuropsychologia_1985
# There's no search result for the id: sim_neuropsychologia_2013
# There's no search result for the id: sim_neuropsychologia_1997
# There's no search result for the id: sim_neuropsychologia_2006
# There's no search result for the id: sim_acta-psychologica_1966
# url: https://archive.org/details/sim_journal-of-cognitive-neuroscience_2000-11_12_6
# url: https://archive.org/details/sim_journal-of-cognitive-neuroscience_2001-08-15_13_6
# There's no search result for the id: sim_memory-cognition_2010
# There's no search result for the id: sim_memory-cognition_2010
# There's no search result for the id: sim_memory-cognition_1982
# There's no search result for the id: sim_memory-cognition_1999
# There's no search result for the id: sim_memory-cognition_1992
# There's no search result for the id: sim_memory-cognition_1990
# url: https://archive.org/details/sim_journal-of-general-psychology_2001-01_128_1
# No close match exist for ids.
# url: https://archive.org/details/sim_neuropsychology_1993-04_7_2
# url: https://archive.org/details/sim_neuropsychology_1997-04_11_2
# There's no search result for the id: sim_neuropsychology_2012
# There's no search result for the id: sim_social-education_2005
# There's no search result for the id: sim_american-journal-of-physical-anthropology_2003
# No close match exist for ids.
# No close match exist for ids.
# url: https://archive.org/details/sim_journal-of-animal-ecology_2002-01_71_1
# There's no search result for the id: sim_bird-study_2004
# There's no search result for the id: sim_organometallics_2010
# There's no search result for the id: sim_medical-history_1977
# There's no search result for the id: sim_skeptical-inquirer_2017
# There's no search result for the id: sim_skeptical-inquirer_1994
# There's no search result for the id: sim_skeptical-inquirer_1995
# There's no search result for the id: sim_skeptical-inquirer_2019
# No close match exist for ids.
# url: https://archive.org/details/sim_nations-and-nationalism_2007-01_13_1
# url: https://archive.org/details/sim_anthropology-today_1985-12_1_6
# url: https://archive.org/details/sim_annals-of-internal-medicine_2007-03-06_146_5
# url: https://archive.org/details/sim_annals-of-internal-medicine_2014-12-16_161_12
# There's no search result for the id: sim_medical-care_2008
# There's no search result for the id: sim_journal-of-physical-chemistry_1993
# url: https://archive.org/details/sim_biophysical-journal_1993-03_64_3
# There's no search result for the id: sim_vision-research_2020
# There's no search result for the id: sim_western-journal-of-nursing-research_2017
# url: https://archive.org/details/sim_neuropsychology-review_1992-06_3_2
# url: https://archive.org/details/sim_current-directions-in-psychological-science_2006-02_15_1
# url: https://archive.org/details/sim_canadian-journal-of-microbiology_2009-05_55_5
# url: https://archive.org/details/sim_antimicrobial-agents-and-chemotherapy_2005-06_49_6
# There's no search result for the id: sim_chemistry-letters_2005
# url: https://archive.org/details/sim_virginia-magazine-of-history-and-biography_1993-04_101_2
# There's no search result for the id: sim_texas-studies-in-literature-and-language_2014
# url: https://archive.org/details/sim_behavioral-and-brain-sciences_2001-02_24_1
# There's no search result for the id: sim_archives-of-gerontology-and-geriatrics_2010
# No close match exist for ids.
# url: https://archive.org/details/sim_journal-of-solar-energy-engineering_2003-11_125_4
# There's no search result for the id: sim_molecular-biology-and-evolution_2007
# There's no search result for the id: sim_molecular-biology-and-evolution_2013
# There's no search result for the id: sim_international-journal-of-legal-medicine_2007
# There's no search result for the id: sim_cytokine-growth-factor-reviews_2010
# No close match exist for ids.
# There's no search result for the id: sim_clinical-and-experimental-immunology_2010
# There's no search result for the id: sim_proceedings-of-the-national-academy-of-sciences-usa_1994
# No close match exist for ids.
# There's no search result for the id: sim_journal-of-near-eastern-studies_1987
# No close match exist for ids.
# url: https://archive.org/details/sim_space-policy_2005-11_21_4
# No close match exist for ids.
# url: https://archive.org/details/sim_organic-biomolecular-chemistry_2011-05-21_9_10
# There's no search result for the id: sim_materials-research-bulletin_2008
# There's no search result for the id: sim_journal-of-applied-physics_2006
# There's no search result for the id: sim_journal-of-applied-physics_2006
# There's no search result for the id: sim_nanotechnology_2009
# There's no search result for the id: sim_materials-letters_2008
# There's no search result for the id: sim_journal-of-materials-science_2009
# url: https://archive.org/details/sim_nucleic-acids-research_1988-02-11_16_3
# There's no search result for the id: sim_applied-physics-letters_2004
# There's no search result for the id: sim_applied-physics-letters_2004
# There's no search result for the id: sim_applied-physics-letters_2005
# There's no search result for the id: sim_applied-physics-letters_2005
# There's no search result for the id: sim_applied-physics-letters_2005
# There's no search result for the id: sim_lanthropologie_2006
# No close match exist for ids.
# There's no search result for the id: sim_journal-of-bacteriology_1929
# There's no search result for the id: sim_physical-review_1934
# There's no search result for the id: sim_physical-review_1931
# There's no search result for the id: sim_journal-of-dairy-science_2004
# There's no search result for the id: sim_journal-of-applied-physiology_2009
# There's no search result for the id: sim_new-england-journal-of-medicine_2011
# There's no search result for the id: sim_bulletin-of-the-american-museum-of-natural-history_1952
# url: https://archive.org/details/sim_bulletin-of-the-american-museum-of-natural-history_1994_221
# There's no search result for the id: sim_new-york-history_1937
# There's no search result for the id: sim_scientific-monthly_1941
# There's no search result for the id: sim_journal-of-educational-psychology_1990
# There's no search result for the id: sim_postgraduate-medical-journal_1980
# There's no search result for the id: sim_journal-of-social-issues_2018
# There's no search result for the id: sim_journal-of-communication_2015
# url: https://archive.org/details/sim_journal-of-communication_2014-12_64_6
# There's no search result for the id: sim_astronomy-and-astrophysics_2008
# url: https://archive.org/details/sim_astronomy-and-astrophysics_1982-08_112_1
# There's no search result for the id: sim_journal-of-infectious-diseases_1945
# There's no search result for the id: sim_education-in-chemistry_2014
# No close match exist for ids.
# url: https://archive.org/details/sim_journal-of-the-royal-asiatic-society_2002-04_12_1
# There's no search result for the id: sim_journal-of-the-royal-asiatic-society_1995
# No close match exist for ids.
# url: https://archive.org/details/sim_psychological-medicine_2007-10_37_10
# url: https://archive.org/details/sim_annals-of-neurology_1992-05_31_5
# There's no search result for the id: sim_developmental-psychology_1998
# There's no search result for the id: sim_child-development_2004
# There's no search result for the id: sim_child-development_2000
# There's no search result for the id: sim_child-development_2014
# url: https://archive.org/details/sim_journal-of-experimental-psychology-applied_2008-09_14_3
# url: https://archive.org/details/sim_american-economic-review_1990-06_80_3
# There's no search result for the id: sim_mining-engineering_2005
# There's no search result for the id: sim_international-journal-of-psychophysiology_2016
# No close match exist for ids.
# url: https://archive.org/details/sim_classical-antiquity_2010-04_29_1
# There's no search result for the id: sim_experimental-techniques_2010
# There's no search result for the id: sim_bulletin-of-the-psychonomic-society_2013
# url: https://archive.org/details/sim_bulletin-of-the-psychonomic-society_1991-05_29_3
# There's no search result for the id: sim_personality-and-social-psychology-bulletin_2015
# There's no search result for the id: sim_cognitive-science_2013
# There's no search result for the id: sim_cognitive-science_1989
# There's no search result for the id: sim_current-psychology_2014
# url: https://archive.org/details/sim_american-psychologist_1986-09_41_9
# url: https://archive.org/details/sim_american-psychologist_february-march-2012_67_2
# There's no search result for the id: sim_learning-and-individual-differences_2012
# There's no search result for the id: sim_american-journal-of-psychotherapy_2006
# There's no search result for the id: sim_radiochemical-and-radioanalytical-letters_1972
# There's no search result for the id: sim_journal-of-semitic-studies_1958
# There's no search result for the id: sim_international-journal-on-world-peace_2003
# No close match exist for ids.
# There's no search result for the id: sim_law-society-review_1991
# There's no search result for the id: sim_international-security_2002
# There's no search result for the id: sim_journal-of-natural-history_2010
# There's no search result for the id: sim_trends-in-genetics_1989
# There's no search result for the id: sim_accounts-of-chemical-research_1998
# No close match exist for ids.
# There's no search result for the id: sim_college-mathematics-journal_2009
# There's no search result for the id: sim_greek-roman-and-byzantine-studies_1963
# There's no search result for the id: sim_applied-animal-behaviour-science_2010
# No close match exist for ids.
# url: https://archive.org/details/sim_motor-trend_2013-02_65_2
# There's no search result for the id: sim_developmental-psychobiology_1978
# There's no search result for the id: sim_infectious-disease-clinics-of-north-america_2013
# There's no search result for the id: sim_infectious-disease-clinics-of-north-america_2013
# There's no search result for the id: sim_infectious-disease-clinics-of-north-america_2013
# There's no search result for the id: sim_infectious-disease-clinics-of-north-america_2013
# There's no search result for the id: sim_infectious-disease-clinics-of-north-america_2013
# There's no search result for the id: sim_clinical-microbiology-reviews_2010
# There's no search result for the id: sim_seminars-in-reproductive-medicine_2014
# There's no search result for the id: sim_seminars-in-reproductive-medicine_2014
# There's no search result for the id: sim_seminars-in-reproductive-medicine_2014
# There's no search result for the id: sim_clinical-infectious-diseases_2015
# There's no search result for the id: sim_journal-of-pediatric-and-adolescent-gynecology_2015
# There's no search result for the id: sim_journal-of-personality_2017
# There's no search result for the id: sim_journal-of-health-and-social-behavior_1998
# There's no search result for the id: sim_review-of-research-in-education_2016
# There's no search result for the id: sim_journal-of-paleontology_1977
# There's no search result for the id: sim_mankind-quarterly
# url: https://archive.org/details/sim_australian-journal-of-international-affairs_2008-09_62_3
# No close match exist for ids.

# %%
possible_url_wo_doi_lst
# Out:
# 5
# 6
# 7
# 8
# 9
#                              ...
# 452
# 453
# 454
# 456    https://archive.org/details/sim_australian-jou...
# 457
# Length: 369, dtype: object

# %%
df_possible_cite_wo_doi["generated_url"] = possible_url_wo_doi_lst
df_possible_cite_wo_doi.head()
# Out:
# /Users/xinyuechen/.pyenv/versions/3.7.5/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                    a                                                  c  \
# 5  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus in Honor...
# 6  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus in Honor...
# 7  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus Honoring...
# 8  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus on Appli...
# 9         Béla Paizs  {{Akademik dergi kaynağı|başlık=Focus in Honor...
#
#                                              journal  \
# 5  Journal of the American Society for Mass Spect...
# 6  Journal of the American Society for Mass Spect...
# 7  Journal of the American Society for Mass Spect...
# 8  Journal of the American Society for Mass Spect...
# 9  Journal of the American Society for Mass Spect...
#
#                                               sim_id     date  year volume  \
# 5  sim_journal-of-the-american-society-for-mass-s...  2011-06  2011     22
# 6  sim_journal-of-the-american-society-for-mass-s...  2013-09  2013     24
# 7  sim_journal-of-the-american-society-for-mass-s...  2017-07  2017     28
# 8  sim_journal-of-the-american-society-for-mass-s...  2018-07  2018     29
# 9  sim_journal-of-the-american-society-for-mass-s...     2012  2012     23
#
#   issue                                              title  page url doi  \
# 5     8  Focus in Honor of David Muddiman, Recipient of...  1299
# 6    11  Focus in Honor of Josh Coon, Recipient of the ...  1621
# 7     9  Focus Honoring Dr. Kristina "Kicki" Håkansson,...  1739
# 8     9  Focus on Application of Photons and Radicals f...  1757
# 9     4  Focus in Honor of Béla Paizs, Recipient of the...   573
#
#                                           PubIssueID  \
# 5  sim_journal-of-the-american-society-for-mass-s...
# 6  sim_journal-of-the-american-society-for-mass-s...
# 7  sim_journal-of-the-american-society-for-mass-s...
# 8  sim_journal-of-the-american-society-for-mass-s...
# 9  sim_journal-of-the-american-society-for-mass-s...
#
#                                                Title NA Gaps  First Volume  \
# 5  Journal of the American Society for Mass Spect...     NaN        1990.0
# 6  Journal of the American Society for Mass Spect...     NaN        1990.0
# 7  Journal of the American Society for Mass Spect...     NaN        1990.0
# 8  Journal of the American Society for Mass Spect...     NaN        1990.0
# 9  Journal of the American Society for Mass Spect...     NaN        1990.0
#
#    Last Volume generated_url
# 5       1993.0
# 6       1993.0
# 7       1993.0
# 8       1993.0
# 9       1993.0

# %%
df_possible_cite_wo_doi_good = df_possible_cite_wo_doi[df_possible_cite_wo_doi["generated_url"] != ""]
print("There are " + str(df_possible_cite_wo_doi_good.shape[0]) + " good urls out of " + str(df_possible_cite_wo_doi.shape[0]))
df_possible_cite_wo_doi_good.head()
# Out:
# There are 92 good urls out of 369
#                           a  \
# 40  Flaş bellek (psikoloji)
# 42  Flaş bellek (psikoloji)
# 43  Flaş bellek (psikoloji)
# 44  Flaş bellek (psikoloji)
# 45  Flaş bellek (psikoloji)
#
#                                                     c  \
# 40  {{Akademik dergi kaynağı|başlık=Autobiographic...
# 42  {{Akademik dergi kaynağı|başlık=The role of im...
# 43  {{Akademik dergi kaynağı|başlık=The role of im...
# 44  {{Akademik dergi kaynağı|başlık=The effects of...
# 45  {{Akademik dergi kaynağı|başlık=FLashbulb memo...
#
#                          journal                            sim_id     date  \
# 40  Applied Cognitive Psychology  sim_applied-cognitive-psychology  2010-02
# 42  Applied Cognitive Psychology  sim_applied-cognitive-psychology  2009-02
# 43  Applied Cognitive Psychology  sim_applied-cognitive-psychology  2009-02
# 44  Applied Cognitive Psychology  sim_applied-cognitive-psychology  2007-12
# 45  Applied Cognitive Psychology  sim_applied-cognitive-psychology     2009
#
#     year volume issue                                              title  \
# 40  2010     24     2  Autobiographical and event memories for surpri...
# 42  2009     23     2  The role of importance/consequentiality apprai...
# 43  2009     23     2  The role of importance/consequentiality apprai...
# 44  2007     21     8  The effects of affect and input source on flas...
# 45  2009     23     5             FLashbulb memory for 11 September 2001
#
#     page url doi                        PubIssueID  \
# 40   177          sim_applied-cognitive-psychology
# 42   236          sim_applied-cognitive-psychology
# 43   236          sim_applied-cognitive-psychology
# 44  1023          sim_applied-cognitive-psychology
# 45   605          sim_applied-cognitive-psychology
#
#                            Title NA Gaps  First Volume  Last Volume  \
# 40  Applied Cognitive Psychology     NaN        1987.0       2010.0
# 42  Applied Cognitive Psychology     NaN        1987.0       2010.0
# 43  Applied Cognitive Psychology     NaN        1987.0       2010.0
# 44  Applied Cognitive Psychology     NaN        1987.0       2010.0
# 45  Applied Cognitive Psychology     NaN        1987.0       2010.0
#
#                                         generated_url
# 40  https://archive.org/details/sim_applied-cognit...
# 42  https://archive.org/details/sim_applied-cognit...
# 43  https://archive.org/details/sim_applied-cognit...
# 44  https://archive.org/details/sim_applied-cognit...
# 45  https://archive.org/details/sim_applied-cognit...

# %%
df_possible_cite_wo_doi_bad = df_possible_cite_wo_doi[df_possible_cite_wo_doi["generated_url"] == ""]
print("There are " + str(df_possible_cite_wo_doi_bad.shape[0]) + " good urls out of " + str(df_possible_cite_wo_doi.shape[0]))
df_possible_cite_wo_doi_bad['sim_id'].value_counts()
# Out:
# There are 277 good urls out of 369
# sim_journal-of-the-american-society-for-mass-spectrometry    17
# sim_psychological-review                                      8
# sim_psychological-science                                     6
# sim_cell                                                      6
# sim_memory-cognition                                          6
#                                                              ..
# sim_strategies                                                1
# sim_trends-in-genetics                                        1
# sim_nature-biotechnology                                      1
# sim_american-journal-of-physical-anthropology                 1
# sim_journal-of-semitic-studies                                1
# Name: sim_id, Length: 159, dtype: int64

# %%
df_cite_wo_doi = df_possible_cite_wo_doi[['a', 'c', 'journal', 'year', 'volume', 'issue', 'title', 'page', 'generated_url']]
df_cite_wo_doi.head()
# Out:
#                    a                                                  c  \
# 5  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus in Honor...
# 6  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus in Honor...
# 7  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus Honoring...
# 8  Biemann Madalyası  {{Akademik dergi kaynağı|başlık=Focus on Appli...
# 9         Béla Paizs  {{Akademik dergi kaynağı|başlık=Focus in Honor...
#
#                                              journal  year volume issue  \
# 5  Journal of the American Society for Mass Spect...  2011     22     8
# 6  Journal of the American Society for Mass Spect...  2013     24    11
# 7  Journal of the American Society for Mass Spect...  2017     28     9
# 8  Journal of the American Society for Mass Spect...  2018     29     9
# 9  Journal of the American Society for Mass Spect...  2012     23     4
#
#                                                title  page generated_url
# 5  Focus in Honor of David Muddiman, Recipient of...  1299
# 6  Focus in Honor of Josh Coon, Recipient of the ...  1621
# 7  Focus Honoring Dr. Kristina "Kicki" Håkansson,...  1739
# 8  Focus on Application of Photons and Radicals f...  1757
# 9  Focus in Honor of Béla Paizs, Recipient of the...   573

# %%
# ### dumb attempt
# def find_actual_identifier(cite_info):
   
    
# #     print(login_data)
# #     count_global += 1
#     gen_ids = cite_info['generated_ids']

#     # we want to check the 4 field (more exact) possibilities first
#     for gen_id in reversed(gen_ids):

#         # perform advanced search on generated identifier
#         session, login_data = initialize_archive_session()
#         search_result = perform_advanced_search(session, login_data, gen_id)

# #       print("Search Result: ")
# #       print(search_result)

#         if search_result != "":


#             # find close match on generated id
#             real_id = find_close_match_from_generated_id(cite_info, search_result)

# #           print("Actual id: " + real_id)

#             if real_id != "":

#                 # actual id
#                 return real_id
            
# #     if count_global % 10 == 0:
# #         print(count_global)
            
#     return ""

# %%
# %%time
# cite_info_test = df_possible_cite.loc[2]
# print(cite_info_test)
# find_actual_identifier(cite_info_test)

# %% [markdown]
# ## Sample
# - since full dataframe takes a while

# %%
sample = df_possible_cite.sample(n = 50)
print(sample.shape)
sample.head()
# Out:
# (50, 18)
#                              a  \
# 960   Şarabın sağlığa etkileri
# 1072           Üre nefes testi
# 1474              Paul Milgrom
# 849          Bedenlenmiş Biliş
# 572         Otar Lortkipanidze
#
#                                                       c  \
# 960   {{Akademik dergi kaynağı|başlık=Alcohol and ca...
# 1072  {{Akademik dergi kaynağı|başlık=Current concep...
# 1474  {{Akademik dergi kaynağı|başlık=A Convergence ...
# 849   {{Akademik dergi kaynağı|başlık=From Firm Musc...
# 572   {{Akademik dergi kaynağı|başlık=Otar Lortkipan...
#
#                               journal                               sim_id  \
# 960           Mayo Clinic Proceedings          sim_mayo-clinic-proceedings
# 1072                              Gut                              sim_gut
# 1474                     Econometrica                     sim_econometrica
# 849      Journal of Consumer Research     sim_journal-of-consumer-research
# 572   American Journal of Archaeology  sim_american-journal-of-archaeology
#
#          date  year  month volume issue  \
# 960   2014-03  2014      3     89     3
# 1072     2007  2007      0     56     6
# 1474     1979  1979      0     47     3
# 849      2011  2011      0     37     6
# 572   2003-01  2003      1    107     1
#
#                                                   title  page url  \
# 960   Alcohol and cardiovascular health: the dose ma...   382
# 1072  Current concepts in the management of Helicoba...   772
# 1474  A Convergence Theorem for Competitive Bidding ...   679
# 849   From Firm Muscles to Firm Willpower: Understan...  1046
# 572                       Otar Lortkipanidze, 1930–2002   105
#
#                                PubIssueID                            Title  \
# 960           sim_mayo-clinic-proceedings          Mayo Clinic Proceedings
# 1072                              sim_gut                              Gut
# 1474                     sim_econometrica                     Econometrica
# 849      sim_journal-of-consumer-research     Journal of Consumer Research
# 572   sim_american-journal-of-archaeology  American Journal of Archaeology
#
#      NA Gaps  First Volume  Last Volume  \
# 960      NaN        1964.0       2015.0
# 1072     NaN        1960.0       2008.0
# 1474     NaN        1933.0       2015.0
# 849      NaN        1974.0       2015.0
# 572      NaN        1885.0       2015.0
#
#                                           generated_ids
# 960   [sim_mayo-clinic-proceedings_2014-03, sim_mayo...
# 1072  [sim_gut_2007, sim_gut_2007, sim_gut_2007_56, ...
# 1474  [sim_econometrica_1979, sim_econometrica_1979,...
# 849   [sim_journal-of-consumer-research_2011, sim_jo...
# 572   [sim_american-journal-of-archaeology_2003-01, ...

# %%
sample["identifier_actual"] = sample.apply(find_actual_identifier, axis = 1)
sample.head()

# %%
sample.head()
# Out:
#                                                       a  \
# 401   2. Dünya Savaşı Sovyetler Birliği silahları li...
# 1635                                          Nebivolol
# 1577                                            Embraer
# 1351                                         Valz Ödülü
# 2174                            Rüzgâr türbini tasarımı
#
#                                                       c  \
# 401   {{Akademik dergi kaynağı|başlık=When Titans Cl...
# 1635  {{Akademik dergi kaynağı|başlık=Nebivolol, a v...
# 1577  {{Akademik dergi kaynağı|başlık=Embraer in Chi...
# 1351  {{Akademik dergi kaynağı|url=https://books.goo...
# 2174  {{Akademik dergi kaynağı|başlık=Alternative Co...
#
#                                        journal_name  \
# 401                                 Foreign Affairs
# 1635  Journal of the American College of Cardiology
# 1577                Aviation Week  Space Technology
# 1351                              Popular Astronomy
# 2174            Journal of Solar Energy Engineering
#
#                                                  sim_id     date  year  month  \
# 401                                 sim_foreign-affairs     1995  1995      0
# 1635  sim_journal-of-the-american-college-of-cardiology  2009-04  2009      4
# 1577                 sim_aviation-week-space-technology  2013-10  2013     10
# 1351                              sim_popular-astronomy     1913  1913      0
# 2174            sim_journal-of-solar-energy-engineering     2003  2003      0
#
#      volume issue                                            article  page  \
# 401      75     3  When Titans Clashed: How the Red Army Stopped ...
# 1635     53    17  Nebivolol, a vasodilating selective beta(1)-bl...  1532
# 1577                                                Embraer in China    60
# 1351     21                                           The Valz Prize
# 2174    125     4  Alternative Composite Materials for Megawatt-S...   515
#
#                                     url  \
# 401
# 1635
# 1577
# 1351  https://books.google.com/books?id
# 2174
#
#                                              PubIssueID  \
# 401                                 sim_foreign-affairs
# 1635  sim_journal-of-the-american-college-of-cardiology
# 1577                 sim_aviation-week-space-technology
# 1351                              sim_popular-astronomy
# 2174            sim_journal-of-solar-energy-engineering
#
#                                               Title  First Volume  \
# 401                                 Foreign Affairs        1922.0
# 1635  Journal of the American College of Cardiology        1983.0
# 1577               Aviation Week & Space Technology        1916.0
# 1351                              Popular Astronomy        1893.0
# 2174            Journal of Solar Energy Engineering        1980.0
#
#       Last Volume                                      identifier_in  \
# 401        2016.0                      sim_foreign-affairs_1995_75_3
# 1635       2014.0  sim_journal-of-the-american-college-of-cardiol...
# 1577       2016.0            sim_aviation-week-space-technology_2013
# 1351       1951.0                      sim_popular-astronomy_1913_21
# 2174       2011.0  sim_journal-of-solar-energy-engineering_2003_1...
#
#      identifier_exact
# 401
# 1635
# 1577
# 1351
# 2174

# %%
# actual_ids = sample['identifier_in'].apply(find_real_identifier_from_generated)
# sample['identifier_out'] = actual_ids
# sample.head()

# %%
sample_wo_id = sample[sample['identifier_actual'] == ""]
print(sample_wo_id.shape)
sample_wo_id.head()
# Out:
# (100, 18)
#                                                       a  \
# 401   2. Dünya Savaşı Sovyetler Birliği silahları li...
# 1635                                          Nebivolol
# 1577                                            Embraer
# 1351                                         Valz Ödülü
# 2174                            Rüzgâr türbini tasarımı
#
#                                                       c  \
# 401   {{Akademik dergi kaynağı|başlık=When Titans Cl...
# 1635  {{Akademik dergi kaynağı|başlık=Nebivolol, a v...
# 1577  {{Akademik dergi kaynağı|başlık=Embraer in Chi...
# 1351  {{Akademik dergi kaynağı|url=https://books.goo...
# 2174  {{Akademik dergi kaynağı|başlık=Alternative Co...
#
#                                        journal_name  \
# 401                                 Foreign Affairs
# 1635  Journal of the American College of Cardiology
# 1577                Aviation Week  Space Technology
# 1351                              Popular Astronomy
# 2174            Journal of Solar Energy Engineering
#
#                                                  sim_id     date  year  month  \
# 401                                 sim_foreign-affairs     1995  1995      0
# 1635  sim_journal-of-the-american-college-of-cardiology  2009-04  2009      4
# 1577                 sim_aviation-week-space-technology  2013-10  2013     10
# 1351                              sim_popular-astronomy     1913  1913      0
# 2174            sim_journal-of-solar-energy-engineering     2003  2003      0
#
#      volume issue                                            article  page  \
# 401      75     3  When Titans Clashed: How the Red Army Stopped ...
# 1635     53    17  Nebivolol, a vasodilating selective beta(1)-bl...  1532
# 1577                                                Embraer in China    60
# 1351     21                                           The Valz Prize
# 2174    125     4  Alternative Composite Materials for Megawatt-S...   515
#
#                                     url  \
# 401
# 1635
# 1577
# 1351  https://books.google.com/books?id
# 2174
#
#                                              PubIssueID  \
# 401                                 sim_foreign-affairs
# 1635  sim_journal-of-the-american-college-of-cardiology
# 1577                 sim_aviation-week-space-technology
# 1351                              sim_popular-astronomy
# 2174            sim_journal-of-solar-energy-engineering
#
#                                               Title  First Volume  \
# 401                                 Foreign Affairs        1922.0
# 1635  Journal of the American College of Cardiology        1983.0
# 1577               Aviation Week & Space Technology        1916.0
# 1351                              Popular Astronomy        1893.0
# 2174            Journal of Solar Energy Engineering        1980.0
#
#       Last Volume                                      identifier_in  \
# 401        2016.0                      sim_foreign-affairs_1995_75_3
# 1635       2014.0  sim_journal-of-the-american-college-of-cardiol...
# 1577       2016.0            sim_aviation-week-space-technology_2013
# 1351       1951.0                      sim_popular-astronomy_1913_21
# 2174       2011.0  sim_journal-of-solar-energy-engineering_2003_1...
#
#      identifier_exact
# 401
# 1635
# 1577
# 1351
# 2174

# %%
sample_w_id = sample[sample['identifier_actual'] != ""]
print(sample_w_id.shape)
sample_w_id.head()
# Out:
# (100, 18)
# Empty DataFrame
# Columns: [a, c, journal_name, sim_id, date, year, month, volume, issue, article, page, url, PubIssueID, Title, First Volume, Last Volume, identifier_in, identifier_exact]
# Index: []

# %% [markdown]
# ### Find urls from actual identifiers

# %%
def generate_url_actual(identifier):
    return "https://archive.org/details/" + identifier

# %%
sample_w_id["generated_url"] = sample_w_id["identifier_actual"].apply(generate_url_actual)
sample_w_id.head()
# Out:
# /Users/xinyuechen/.pyenv/versions/3.7.5/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                     journal_name  \
# 662                                    Billboard
# 1072  Journal of Deaf Studies and Deaf Education
# 180                                      Science
# 1060                                   Neurology
#
#                                               sim_id     date  year  month  \
# 662                                    sim_billboard  1990-12  1990     12
# 1072  sim_journal-of-deaf-studies-and-deaf-education     2004  2004      0
# 180                                      sim_science     1934  1934      0
# 1060                                   sim_neurology  2008-04  2008      4
#
#      volume issue  page                                                url  \
# 662                Y-50  https://archive.org/details/VOA_Africa_2018010...
# 1072      9     2   239  https://archive.org/details/sim_journal-of-dea...
# 180      80  2084   512  https://archive.org/details/sim_science_1934-1...
# 1060     70    18  1630  https://archive.org/details/sim_jama-psychiatr...
#
#                                           PubIssueID  \
# 662                                    sim_billboard
# 1072  sim_journal-of-deaf-studies-and-deaf-education
# 180                                      sim_science
# 1060                                   sim_neurology
#
#                                            Title  First Volume  Last Volume  \
# 662                                    Billboard        1894.0       2016.0
# 1072  Journal of Deaf Studies and Deaf Education        1999.0       2007.0
# 180                                      Science        1883.0       2016.0
# 1060                                   Neurology        1951.0       2012.0
#
#                                           identifier_in  \
# 662                                  sim_billboard_1990
# 1072  sim_journal-of-deaf-studies-and-deaf-education...
# 180                                 sim_science_1934_80
# 1060                              sim_neurology_2008_70
#
#                                          identifier_out
# 662                          VOA_Africa_20180105_150000
# 1072  sim_journal-of-deaf-studies-and-deaf-education...
# 180                      sim_science_1934-11-16_80_2081
# 1060                   sim_jama-psychiatry_2008-06_65_6

# %% [markdown]
# #### No need to do this since advance search generated results must be good

# %%
# def test_url_exist(url):
#     request = requests.get(url)
#     if request.status_code == 200:
#         return True
#     else:
#         return False

# %%
# sample_w_id["url_exists"] = sample_w_id["url"].apply(test_url_exist)
# sample_w_id.head()
# Out:
# /Users/xinyuechen/.pyenv/versions/3.7.5/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                     journal_name  \
# 662                                    Billboard
# 1072  Journal of Deaf Studies and Deaf Education
# 180                                      Science
# 1060                                   Neurology
#
#                                               sim_id     date  year  month  \
# 662                                    sim_billboard  1990-12  1990     12
# 1072  sim_journal-of-deaf-studies-and-deaf-education     2004  2004      0
# 180                                      sim_science     1934  1934      0
# 1060                                   sim_neurology  2008-04  2008      4
#
#      volume issue  page                                                url  \
# 662                Y-50  https://archive.org/details/VOA_Africa_2018010...
# 1072      9     2   239  https://archive.org/details/sim_journal-of-dea...
# 180      80  2084   512  https://archive.org/details/sim_science_1934-1...
# 1060     70    18  1630  https://archive.org/details/sim_jama-psychiatr...
#
#                                           PubIssueID  \
# 662                                    sim_billboard
# 1072  sim_journal-of-deaf-studies-and-deaf-education
# 180                                      sim_science
# 1060                                   sim_neurology
#
#                                            Title  First Volume  Last Volume  \
# 662                                    Billboard        1894.0       2016.0
# 1072  Journal of Deaf Studies and Deaf Education        1999.0       2007.0
# 180                                      Science        1883.0       2016.0
# 1060                                   Neurology        1951.0       2012.0
#
#                                           identifier_in  \
# 662                                  sim_billboard_1990
# 1072  sim_journal-of-deaf-studies-and-deaf-education...
# 180                                 sim_science_1934_80
# 1060                              sim_neurology_2008_70
#
#                                          identifier_out  url_exists
# 662                          VOA_Africa_20180105_150000        True
# 1072  sim_journal-of-deaf-studies-and-deaf-education...        True
# 180                      sim_science_1934-11-16_80_2081        True
# 1060                   sim_jama-psychiatry_2008-06_65_6        True

# %% [markdown]
# ## Add URL to citation

# %%
# perform_advanced_search("sim_review_2004_86")

# %%
def generate_new_citation(citation, url):
    url_field = "| url=" + url
    return citation[:-2] + url_field + "}}"

# %%
test = perform_advanced_search("sim_applied-cognitive-psychology_2007_21")
test
# Out:
# {'sim_applied-cognitive-psychology_2007_21_index-contents': 75.87896}

# %%
test2 = perform_advanced_search("sim_american-journal-of-archaeology_2000-10_104_4")
test2
# Out:
# {'sim_american-journal-of-archaeology_2001_105_contents': 1486.7208}

# %% [markdown]
# ### Write Data to Google Sheet

# %%
import gspread
from gspread_dataframe import set_with_dataframe

# %%
gc = gspread.service_account("service_account.json")

sh = gc.open("Citations SIM Test")

print(sh.sheet1.get('A1'))
# Out:
# [['a']]

# %%
# ACCESS GOOGLE SHEET
gc = gspread.service_account(filename='service_account.json')
sh = gc.open_by_key('1ih5bIk5_d5WLEtArRzEFPzPlwZVA_BI-O8kSxWH1rNU')
worksheet = sh.get_worksheet(2) #-> 0 - first sheet, 1 - second sheet etc. 

# APPEND DATA TO SHEET
df_to_write = df_cite_wo_doi
set_with_dataframe(worksheet, df_to_write) #-> THIS EXPORTS YOUR DATAFRAME TO THE GOOGLE SHEET
